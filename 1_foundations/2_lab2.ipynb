# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
gemini_api_key = os.getenv('GEMINI_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if gemini_api_key:
    print(f"Gemini API Key exists and begins {gemini_api_key[:2]}")
else:
    print("Gemini API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Gemini API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content

import textwrap

print(question)
# print(textwrap.fill(question, width=80))
# Out:
# You are an independent consultant asked to produce a single, council-ready report for a mid-sized city whose AI-based predictive policing system has been shown to disproportionately target minority neighborhoods; in that report, please do all of the following: (1) identify and clearly distinguish the plausible technical and non-technical causes of the disparity (e.g., biased training data, label bias, feedback loops, policing practices, socio-economic confounders, deployment decisions); (2) propose a prioritized, feasible 12‑month remediation plan that includes immediate safeguards, data and model audits, changes to deployment and decision-making processes, community engagement and oversight mechanisms, and policy or contractual changes with vendors; (3) for each action in the plan, estimate the expected impact on disparity and public safety, the human and financial resources required, an implementation timeline, and the most likely unintended consequences or risks; (4) design a protocol for an independent audit that would detect whether the system continues to produce disparate harms, specifying what data to collect, what statistical and causal tests to run, acceptable thresholds for action, and how to ensure auditor independence and transparency; (5) explain a principled framework the council can use to trade off predictive accuracy, public safety, and civil‑rights protections (including how to operationalize fairness criteria, when to accept reductions in accuracy, and how to monitor outcomes over time); and (6) list the top five specific factual questions you would ask city officials or vendors to refine your recommendations, and explain how different plausible answers to each would change your prioritized actions; cite relevant principles, empirical findings or precedents where appropriate, and for each major recommendation state your confidence level and the key uncertainties that could alter your advice—what do you recommend the council do now, and why?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Council-ready report: Addressing disparities in an AI-based predictive policing system
#
# Date: [Insert date]
#
# Executive summary
# - Problem: An AI-driven predictive policing system is disproportionately flagging minority neighborhoods, raising civil-rights concerns and eroding public trust.
# - Core finding: Disparities arise from a mix of technical causes (biased historical data, label bias, feedback loops, feature leakage, data quality gaps) and non-technical causes (policing practices, deployment choices, socio-economic confounders, governance and contractor practices).
# - Plan: A 12-month remediation program combining immediate safeguards, data/model audits, deployment/process changes, community oversight, and binding vendor policy changes; plus an independent audit protocol and a principled framework to balance accuracy, public safety, and civil rights.
# - Outcome sought: Reduced bias in predictions while preserving or improving public safety, with transparent, auditable processes and robust community oversight.
#
# 1) Plausible causes of disparity: technical vs. non-technical
# A. Technical causes
# - Biased training data
#   - Historical policing records reflect prior enforcement biases (e.g., over-policing in minority neighborhoods), creating biased predictive signals.
# - Label bias
#   - The target variable (crime labels, arrests, gun detections) may reflect enforcement practices and not true underlying risk, injecting label bias.
# - Feedback loops
#   - Predicted risk drives policing activity in certain areas, generating more incident data there and reinforcing the model’s belief that those areas are high risk (self-fulfilling loop).
# - Data quality and representation gaps
#   - Missing data, under-reporting in some communities, or insufficient coverage of certain geographies skew model training.
# - Feature biases and leakage
#   - Proximity to police facilities, prior stop frequencies, or census-geography proxies can act as proxies for sensitive attributes; models may learn spurious correlations with protected groups.
# - Model design choices
#   - Complexity or training procedures that optimize overall accuracy at the expense of fairness; failure to calibrate scores across groups.
# - Temporal drift and nonstationarity
#   - Crime patterns shift; models trained on older data misrepresent current risk, potentially differentially affecting groups.
# B. Non-technical causes
# - Policing practices and policy
#   - Law enforcement priorities, discretionary stops, or geofenced deployment that concentrate effort in particular neighborhoods.
# - Deployment decisions and governance
#   - Where and how predictions influence action (e.g., early-warning flags vs. reactive discretion) shapes how disparities translate into outcomes.
# - Socio-economic confounders
#   - Structural inequalities (poverty, housing, education, limited legitimate opportunities) correlate with crime metrics and neighborhood demographics, confounding causal interpretation.
# - Vendor and procurement factors
#   - Contracts that emphasize predictive accuracy without fairness requirements; opaque model provenance; lack of independent audits.
# - Community trust and data sharing
#   - Under-resourced communities may have lower engagement or reporting rates, affecting data representativeness.
#
# Notes on causality and interpretation
# - Many causes are interdependent. For example, biased training data + feedback loops + policing deployment choices can magnify disparities even when the underlying model is technically well-behaved.
# - Distinguishing between short-term remediation (e.g., threshold re-calibration) and long-term systemic reform (e.g., governance reforms, data collection improvements) is essential.
#
# 2) A prioritized, feasible 12-month remediation plan
# Guiding principles
# - Immediate safeguards first: ensure human review, prohibit automatic discretionary actions based solely on risk scores, and place a cap on high-stakes decisions driven by the model.
# - Data and model transparency: audits, audits, audits—internal and independent.
# - Community oversight: establish protections and channels for affected communities; publish aggregate metrics and progress.
# - Vendor accountability: contractually bind fairness, transparency, and audit rights.
#
# 12-month plan (action-by-action overview; owners in parentheses)
# A1. Immediate safeguards for deployment (0–1 month)
# - What: Prohibit automatic enforcement actions solely based on model output; require a human-in-the-loop for high-risk decisions; implement a “watchlist” to flag anomalous scores for review.
# - Expected impact: Moderate reduction in excessive reliance on predictions; limit potential harm in the near term.
# - Resources: Policy staff, field supervisors, IT to enforce controls.
# - Timeline: 0–4 weeks.
# - Risks: Slower response in emergencies; potential backlog; need clear guidelines for human decision-makers.
# - Confidence: High; uncertainties relate to operational enforcement.
#
# A2. Enforce data lineage and governance (0–2 months)
# - What: Inventory data sources, define data lineage, retention, and access controls; map which features derive from historical policing behavior vs. real-time context.
# - Expected impact: Improves ability to diagnose bias sources; reduces leakage of biased signals.
# - Resources: Data governance team; IT security; legal review.
# - Timeline: 0–8 weeks.
# - Risks: Resource-intensive; potential pushback from data producers.
# - Confidence: High.
#
# A3. Independent bias and fairness audit (0–3 months)
# - What: Commission an independent audit to assess fairness metrics (calibration by group, equalized odds, demographic parity), identify proxies for sensitive attributes, review data sampling and targets.
# - Expected impact: Establish baseline and concrete remediation targets; increase trust.
# - Resources: External audit firm, internal liaison.
# - Timeline: RFP in month 0–1; audit in months 1–3.
# - Risks: Auditor access to data; confidentiality considerations.
# - Confidence: High.
#
# A4. Debias training data and feature engineering (1–4 months)
# - What: Apply techniques to mitigate bias in training data (reweighting, resampling, causal modeling where feasible), remove or limit use of problematic proxies; consider using counterfactual fairness or causal risk models.
# - Expected impact: Reduce historical bias transmission; improve fairness metrics.
# - Resources: Data science team; compute; possible external expertise.
# - Timeline: 1–4 months.
# - Risks: Potential reduction in overall predictive performance; need to monitor for unintended effects.
# - Confidence: Medium-High.
#
# A5. Calibration and thresholding for equalized outcomes (2–5 months)
# - What: Re-calibrate scores by demographic group; adjust decision thresholds to achieve specified fairness objectives (e.g., equalized false positive rates or equal misclassification costs) while maintaining acceptable overall accuracy.
# - Expected impact: Direct reduction in disparate impacts; more uniform operation across groups.
# - Resources: Data scientists; policy/operations teams; governance oversight.
# - Timeline: 2–6 months.
# - Risks: Trade-off with accuracy; threshold drift over time needs ongoing monitoring.
# - Confidence: High.
#
# A6. Mitigate feedback loops with drift detection (2–6 months)
# - What: Implement monitoring for data drift and model drift; insert mechanisms to decouple current policing activity from model-generated data where feasible; refresh training data with more representative samples.
# - Expected impact: Stability against self-reinforcing biases; better long-run equity.
# - Resources: Data science + engineering; monitoring dashboards.
# - Timeline: 2–6 months.
# - Risks: Complexity of measuring drift in criminal data; requires ongoing maintenance.
# - Confidence: Medium-High.
#
# A7. Deployment governance and use-case refinement (3–7 months)
# - What: Define clear use cases for predictions (e.g., resource allocation planning vs. operational preemption); restrict areas or situations where scores drive decisions; require human decision-makers to consider context.
# - Expected impact: Reduces overbroad application of predictions; aligns with civil-rights safeguards.
# - Resources: Policy, legal, operations.
# - Timeline: 3–7 months.
# - Risks: Potential reduction in some predictive benefits; need careful communication with staff.
# - Confidence: High.
#
# A8. Community engagement and oversight mechanisms (4–8 months)
# - What: Establish Community Advisory Board (CAB), public dashboards with aggregate metrics, town halls, and a public data access policy for aggregated results; ensure accessible, multilingual communications.
# - Expected impact: Increased legitimacy, improved data quality through local feedback; stronger social license to operate.
# - Resources: Community relations; communications; data team.
# - Timeline: 4–8 months.
# - Risks: Potential politicization; must maintain privacy and security controls.
# - Confidence: High.
#
# A9. Vendor policy and procurement reforms (4–12 months)
# - What: Include fairness-by-design requirements in contracts; require model cards, audit rights, data provenance, versioning, and remediation plans; specify penalties for noncompliance; require third-party audits at defined intervals.
# - Expected impact: Structural incentive for fairness and transparency; clear accountability.
# - Resources: Legal, procurement, policy teams; potential legal reviews.
# - Timeline: 4–12 months.
# - Risks: Vendor resistance; negotiation complexity.
# - Confidence: High.
#
# A10. Public-facing transparency and educational materials (5–12 months)
# - What: Publish high-level model governance, fairness metrics, and remediation steps; avoid exposing sensitive details that could enable manipulation; provide resources for community members to understand policing changes.
# - Expected impact: Maintains trust and civic engagement; reduces speculation.
# - Resources: Communications; privacy/compliance.
# - Timeline: 5–12 months.
# - Risks: Privacy and security concerns; risk of misinterpretation.
# - Confidence: Medium-High.
#
# A11. Ongoing independent monitoring framework (6–12+ months)
# - What: Establish continuous independent evaluation, with quarterly public reports; annual full audit; data access controls for auditors; integrate independent feedback loops into governance.
# - Expected impact: Sustained accountability and long-term improvement.
# - Resources: Independent auditor commitments; governance body; IT for data access.
# - Timeline: Launch by month 6; ongoing thereafter.
# - Risks: Sustained funding and independence; confidentiality.
# - Confidence: High.
#
# A12. Contingency pause or re-engineering if targets not met (12 months)
# - What: If disparity metrics remain outside targets after full remediation window, pause deployment in affected geographies and pivot to non-predictive approaches or comprehensive reforms; re-evaluate system design.
# - Expected impact: Strong signal that civil-rights protections take priority; avoids perpetuating harm.
# - Resources: Governance and budget approvals.
# - Timeline: Triggered at 12 months if needed.
# - Risks: Public safety concerns; political ramifications.
# - Confidence: High; uncertainty about feasible alternatives.
#
# How these actions map to impact and resources
# - Impact on disparity: Most direct reductions from A3, A5, A6, A7, A9, A11; measurable improvements expected within 6–12 months if implemented rigorously.
# - Impact on public safety: Maintained or improved through careful calibration, human-in-the-loop processes, and governance; risk of short-term dip if thresholds restrict some predictive utility; mitigated by improved data quality and targeted interventions.
# - Human resources: 4–8 FTEs for governance, data science, and policy; external auditors for A3/A11; ongoing vendor management staff; community liaison roles.
# - Financial resources: Budget for audits, software governance tools, potential re-architecture, contract changes, and community engagement activities.
# - Timeline: Phased, with quick wins within 0–3 months (A1–A3) and longer-term governance and vendor changes by 6–12 months (A8–A11). Contingency action (A12) if targets not met.
#
# 3) Independent audit protocol to detect ongoing disparate harms
# Purpose
# - Detect whether the system continues to produce disparate harms and to attribute root causes.
#
# Data to collect (with privacy and legal guardrails)
# - Aggregated, de-identified incident-level data linked to model predictions, outcomes, and geographies (e.g., census tracts or neighborhoods) with time stamps.
# - Predicted risk scores and corresponding real-world outcomes (whether an incident occurred, arrests, or verified crimes).
# - Group-level identifiers allowed by law and policy (e.g., race/ethnicity proxies at aggregate level, or neighborhood-level demographic composition). Use synthetic or grouped data if individual attributes cannot be disclosed.
# - Deployment context data: policing posture in each area, officer density, time-of-day, resource allocation.
#
# Tests and analyses (in a protocol)
# - Fairness tests:
#   - Calibration by group: compare predicted risk to observed outcomes within each group; check calibration slope and intercept per group.
#   - Equalized odds: compare TPR and FPR across groups; ensure gaps are within predefined thresholds (e.g., <= 0.05 difference in TPR and FPR).
#   - Demographic parity (where legally permissible): compare positive prediction rates by group; target disparity <= 0.05 in absolute difference or within 0.8–1.25 ratio range.
# - Causal and quasi-experimental tests:
#   - Propensity score weighting to adjust for socio-economic confounders; examine residual association between group membership and predictions after adjustment.
#   - Difference-in-differences around policy changes to assess whether interventions affect disparities.
#   - Sensitivity analyses for unmeasured confounding in the observed disparities.
# - Robustness and leakage checks:
#   - Feature attribution and SHAP-like explanations to identify proxies for sensitive attributes; remove or constrain problematic features.
#   - Temporal drift analyses to detect shifts in data distribution and model behavior.
# - Validation and governance checks:
#   - Reproducibility: fixed data windows, versioned data, and model cards for each release.
#   - Audit trails: complete logs of data used, features, model versions, predictions, and human actions taken.
#
# Thresholds for action (indicators to trigger remediation)
# - If calibration by group deviates from 1.0 by more than ±0.1 for any group, trigger recalibration and potential feature removal.
# - If equalized odds gaps exceed ±0.05 in TPR or FPR for any group for two consecutive quarterly audits, trigger remediation (A5/A6) and governance review.
# - If demographic parity differences exceed ±0.05 across multiple geographies for two consecutive audits, pause or re-scope deployment in those geographies (A7/A12).
# - If persistent drift is detected without remediation after two cycles, escalate to independent governance body and consider vendor changes (A9/A11).
#
# Auditor independence and transparency
# - Auditing body must be legally and organizationally independent from the city’s policing apparatus and from the vendor.
# - Public summary reports released on a regular cadence; full, detailed reports available to the council and the independent oversight board, with redactions where necessary to protect privacy.
# - Access to data and model artifacts governed by data-sharing agreements, with strict confidentiality and security protocols.
# - Auditor selection: competitive tender, rotation of lead auditors every 3–5 years; annual performance review and public disclosure of qualifications.
# - Transparency: publish model cards, data schemas, and fairness metrics in a publicly accessible dashboard, with user-friendly explanations for non-technical stakeholders.
#
# 4) A principled framework for trading off predictive accuracy, public safety, and civil-rights protections
# Core objective
# - Maximize public safety while meeting explicit civil-rights protections and maintaining accountable governance.
#
# Operationalization steps
# - Define objective function with constraints:
#   - Primary objective: maximize net public safety benefit (e.g., reductions in crime rates, reductions in violent incidents) and minimize harms caused by false positives.
#   - Constraints: maintain fairness thresholds (calibration by group, equalized odds, and, where legally permissible, demographic parity) within specified bounds; require human oversight for high-risk predictions; preserve privacy and civil liberties.
# - Fairness criteria selection (practical guidance):
#   - Use multiple fairness notions to capture different harms; no single metric will satisfy all fairness criteria due to known impossibility results (Kleinberg et al. 2016/2017). Report trade-offs among metrics and justify choices.
#   - Calibrate the model by group so that each group’s observed risk aligns with predicted risk (calibration within groups).
#   - Choose a preferred fairness constraint (e.g., equalized odds or equalized calibration) based on policy priorities and legal requirements; consider multiple models or operating points to illustrate trade-offs.
# - Operational thresholds and accept/reject rules:
#   - If the model’s fairness metrics cannot be brought into alignment without unacceptable losses in predictive utility, constrain usage to non-discretionary, non-actionable predictions for certain contexts; emphasize human-centered decision processes.
#   - Maintain a policy of “no automated discretionary action without human review” for high-risk predictions, especially those that would trigger stops or detentions.
# - Monitoring and learning loop:
#   - Establish quarterly reviews of both accuracy and fairness metrics; adjust thresholds and training data with the independent audit’s recommendations.
#   - Introduce a governance veto on deploying changes that would meaningfully degrade civil-rights protections.
# - Time horizon and signaling:
#   - Short-term operationalization: prioritize constraints and human-in-the-loop processes; demonstrate improvements in fairness metrics within 6–12 months.
#   - Long-term sustainability: embed continuous fairness evaluation in standard practice (A3–A11) and ensure community oversight is ongoing.
#
# Operationalizing fairness and monitoring
# - Use model cards and data sheets for transparency (documentation of data sources, model inputs, performance metrics by group, and limitations).
# - Publish accessible dashboards showing aggregated metrics (crime outcomes, false positives, resource allocation) across geographies and over time.
# - Establish triggers for governance reviews if disparities widen or if performance degrades beyond agreed thresholds.
#
# Key uncertainties and how they could affect recommendations
# - If legal restrictions limit collection of sensitive attributes or group proxies, fairness verification may rely on proxy measures (uncertainties in their validity). Plan alternative proxies and document limitations.
# - If the city cannot attain acceptable fairness thresholds without sacrificing too much predictive accuracy, the framework suggests restricting deployment to non-predictive uses or reducing scope, with public communication and community involvement.
# - If historical crime rates in certain neighborhoods reflect under-reporting or other data issues, fairness tests may overstate disparities; the audit protocol includes causal analyses to address this.
# - Vendor capabilities vary; if a vendor cannot meet fairness-by-design requirements within budget, plan for competitive procurement and longer-term reengineering with phasing to avoid operational disruption.
# - Unintended consequences: tightening safeguards may reduce predictive utility in the short term, potentially affecting legitimate crime prevention efforts; this must be transparently communicated and mitigated with improved data quality and governance.
#
# 5) The top five factual questions to city officials or vendors (and how answers would shift actions)
# Question 1: What data sources feed the predictive model, and to what extent do they reflect policing practices or past enforcement priorities?
# - Plausible answer implications:
#   - If data are heavily biased by past enforcement, treat as a top-priority bias source (A3–A6) requiring data reweighting, removal of biased proxies, and increased emphasis on real-time contextual features; prioritize data governance and audit remediation (A2, A3, A5).
#   - If data reflect broader crime indicators with limited policing bias, fairness remediation may focus more on thresholds and governance rather than data removal (A5, A7).
# Question 2: Does the vendor provide a formal model card and a documented fairness assessment, including calibration by group and equalized odds analyses?
# - Plausible answer implications:
#   - If not, initiate binding contractual requirements for fairness testing, independent audits, and model-card disclosures (A9, A3, A11).
#   - If yes but with limited granularity, demand more rigorous, public-facing dashboards and independent audit validation (A11, A3).
# Question 3: What safeguards exist around human-in-the-loop decisions, and how are high-risk predictions handled in practice?
# - Plausible answer implications:
#   - If safeguards are weak, implement immediate A1 safeguards and strengthen deployment policy (A1, A7).
#   - If safeguards are strong, focus on governance improvements and more robust monitoring to ensure consistent human oversight (A7, A11).
# Question 4: What data-sharing and privacy protections apply to data used for audits and model evaluation, and who can access them?
# - Plausible answer implications:
#   - If access is too restricted, push for independent audits with legally defined data access windows and redacted data, per A3 and A11.
#   - If access is already appropriate, ensure ongoing transparency via public dashboards and annual audit reports (A8, A11).
# Question 5: What remedies exist if disparities persist after remediation (e.g., pause, re-engineering, or reallocation of resources)?
# - Plausible answer implications:
#   - If remedies exist and are actionable (A12), prepare for contingent actions; if remedies are weak or ambiguous, advocate for a governance framework with explicit triggers and public reporting (A12, A11, A8).
#
# 6) Confidence levels and key uncertainties for major recommendations
# - Immediate safeguards (A1): Confidence high; risk of emergency response delays is manageable with clear guidelines for urgent scenarios. Uncertainty: how best to define “high-risk” conditions for automatic human review.
# - Data lineage and governance (A2): Confidence high; essential for traceability. Uncertainty: comprehensiveness across all data sources; possible unidentified data flows.
# - Independent bias/fairness audit (A3): Confidence high; foundational for credibility. Uncertainty: scope of access and potential confidentiality constraints.
# - Debias training data (A4): Confidence medium-high; can reduce historical bias but may impact predictive performance. Uncertainty: which features are truly causal versus proxies; risk of over-correction.
# - Calibration and thresholding (A5): Confidence high; directly addresses fairness across groups. Uncertainty: optimal trade-offs between fairness and accuracy in different contexts.
# - Drift detection and feedback loop mitigation (A6): Confidence medium-high; feasible with modern monitoring, but effectiveness depends on data availability and timely model retraining.
# - Deployment governance (A7): Confidence high; operationally critical to ensure appropriate use. Uncertainty: balance between staffing and responsiveness; potential slowdowns in urgent responses.
# - Community engagement (A8): Confidence high; improves trust and legitimacy. Uncertainty: long-term engagement effects and possible politicization.
# - Vendor policy reform (A9): Confidence high; aligns incentives. Uncertainty: vendor capacity to comply; contract negotiation complexity.
# - Public transparency (A10): Confidence medium-high; enhances accountability but must protect privacy. Uncertainty: how much detail can be publicly shared without compromising security.
# - Ongoing independent monitoring (A11): Confidence high; essential for accountability. Uncertainty: funding sustainability; independence maintenance over time.
# - Contingency plan (A12): Confidence high; provides a clear path to protection if remediation stalls. Uncertainty: political and operational feasibility of pausing deployments.
#
# What the council should do now, and why
# - Immediately tighten governance and safeguards (A1–A3): Establish human oversight, halt unreviewed automated actions, and begin an independent bias/audit baseline. This reduces risk of ongoing harms while you work on longer-term remediation.
# - Commission independent audits (A3) and begin data lineage work (A2): These steps identify root causes and establish a credible road map for remediation; they are foundational for all subsequent actions.
# - Initiate bias correction and fairness calibration (A4–A5): Debias training data and recalibrate risk scores across groups to reduce disparities without sacrificing public safety, as much as possible.
# - Establish community engagement and oversight (A8) and strengthen vendor accountability (A9): Build legitimacy and ensure that the system reflects community values and legal obligations.
# - Implement ongoing monitoring and an independent monitoring framework (A11): Ensure sustained accountability and continuous improvement; publish transparent reports (A10) to maintain trust.
# - Prepare for a contingency pause or re-engineering if targets aren’t met (A12): Demonstrates that civil-rights protections are paramount and provides a clear exit pathway if remediation stalls.
#
# Key precedents, principles, and empirical grounding
# - Disparities in predictive policing documented in Lum & Isaac (2016), ProPublica COMPAS analysis (2016), and follow-up critiques; highlight that data and societal bias can manifest in algorithmic outputs.
# - Fairness impossibility results (Kleinberg, Mullainathan, Raghavan; Kleinberg et al., 2016, 2017) showing that equalizing all fairness metrics simultaneously is generally impossible when base rates differ; the framework here uses multiple metrics and explicit trade-offs rather than a single “perfect” metric.
# - Barocas & Selbst (2016) on bias in algorithmic decision-making and the necessity of governance, transparency, and human oversight.
# - NIST AI RMF and related governance literature emphasize risk management, transparency, accountability, and independent auditing as core pillars for responsible AI in public sector use.
#
# Confidence statements and uncertainties
# - The strongest action cluster (A1–A3, A7–A9) has high confidence because it directly reduces the likelihood of ongoing harm, creates governance mechanisms, and compels vendors to align with fairness and transparency obligations.
# - The data- and model-centric actions (A4–A6) depend on data quality and the ability to disentangle causality; they are likely to yield improvements but require careful implementation to avoid unintended performance losses.
# - Community engagement (A8) is essential for legitimacy; however, its effectiveness depends on sustained commitment, resource allocation, and the willingness of residents to participate meaningfully.
# - The long-term monitoring (A11) and transparency (A10) are essential but rely on sustained funding and political support.
# - The contingency option (A12) is prudent but may carry political and operational risk if invoked.
#
# Executive recommendation: what the council should do now
# - Approve an immediate, tightly scoped set of safeguards (A1) and commission an independent bias/fairness audit (A3) while initiating data governance work (A2). This provides immediate risk reduction and a credible baseline.
# - Simultaneously begin fairness calibration (A5) and establish a deployment governance framework (A7) to ensure any future use of predictions is context-aware and human-in-the-loop.
# - Launch a Community Advisory Board (A8) and contract a formal vendor reform path (A9) to ensure civil-rights protections and transparency.
# - Establish ongoing independent monitoring (A11) with quarterly public reports (A10) to maintain accountability and continuous improvement.
# - If, after 12 months, disparities persist beyond agreed thresholds, activate the contingency pause or re-engineering plan (A12) and reassess the system’s role in public safety.
#
# Final note
# - The city should recognize that fairness and safety are not binary choices but a spectrum of trade-offs. The recommended plan emphasizes governance, transparency, independent assessment, and community involvement as the pillars for restoring equity and public trust while preserving legitimate crime prevention goals. The actions are designed to be implementable within a 12-month frame, with a clear auditable path and measurable milestones.
#
# Appendix: Suggested metrics to track (examples)
# - Disparity metrics: disparate impact ratio (minority vs nonminority positive rate), equalized odds gap (TPR/FPR differences by group), calibration slope by group.
# - Predictive performance: AUC/ROC by group, Brier score overall and by group.
# - Process metrics: time from prediction to action, number of high-risk predictions reviewed by humans, number of interventions deployed per month.
# - Governance metrics: number of audit findings resolved, vendor compliance incidents, community meeting attendance and sentiment, data access requests fulfilled.
#
# If you would like, I can tailor the actions, timelines, and metrics to the city’s existing budgets, governance structures, and vendor contracts, and provide a one-page executive briefing for council members.

# %%
# if anthropic_api_key:
#     try:
#         claude = Anthropic()
#         response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
#         answer = response.content[0].text
#     except Exception as e:
#         answer = f"Anthropic call failed: {e}"
# else:
#     answer = "Anthropic API key not set; skipping."

# display(Markdown(answer))

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-6"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# # PREDICTIVE POLICING DISPARITY: COMPREHENSIVE COUNCIL REPORT
#
# ## Prepared for the City Council | Independent Consultant Assessment
#
# ---
#
# > **Executive Summary**
# >
# > This report presents findings and recommendations regarding demonstrated racial and geographic disparities in the city's AI-based predictive policing system. The evidence base for algorithmic bias in predictive policing is substantial and growing; disparity in this system is neither surprising nor inevitable, but it demands structured, urgent response. I recommend the council immediately suspend autonomous decision-making authority vested in the system, establish independent oversight, and pursue a 12-month remediation plan detailed herein. The cost of inaction—continued civil rights harm, litigation exposure, community trust erosion, and likely federal scrutiny—substantially exceeds the cost of remediation. My confidence in the core diagnosis is high; my confidence in specific technical fixes is moderate, contingent on answers to factual questions identified in Section VI.
#
# ---
#
# ## TABLE OF CONTENTS
#
# 1. Causes of Disparity: Technical and Non-Technical
# 2. 12-Month Prioritized Remediation Plan
# 3. Action-by-Action Impact and Resource Analysis
# 4. Independent Audit Protocol
# 5. Principled Framework for Balancing Accuracy, Safety, and Civil Rights
# 6. Key Factual Questions for City Officials and Vendors
# 7. Immediate Recommendations and Rationale
# 8. References and Precedents
#
# ---
#
# ## SECTION I: CAUSES OF DISPARITY — TECHNICAL AND NON-TECHNICAL
#
# Understanding *why* the system produces disparate outcomes is essential before prescribing solutions. The causes are almost certainly multiple, interactive, and mutually reinforcing. I distinguish seven categories below.
#
# ### 1.1 Technical Causes
#
# #### 1.1.1 Biased Training Data (Historical Crime Records)
#
# **What it is:** The model was trained on historical arrest, stop, citation, or crime report data that itself reflects prior discriminatory policing patterns.
#
# **Why it matters:** If police historically concentrated enforcement in minority neighborhoods—whether due to explicit policy, implicit bias, or political decisions—arrest and citation records will overrepresent those neighborhoods even if underlying criminal behavior is distributed differently across the city. Training a model on this data does not reveal ground truth about crime; it reveals ground truth about *prior police behavior*. The model then predicts where police made arrests, not necessarily where crime occurs. This is sometimes called the "dirty data" problem, documented systematically by researchers including Rashida Richardson and colleagues (2019) in their examination of "dirty data" cities.
#
# **Confidence this is present:** High. Nearly every predictive policing deployment using historical crime data is susceptible to this problem. The observed disparity is consistent with this mechanism.
#
# #### 1.1.2 Label Bias
#
# **What it is:** The outcome variable (the "label") the model is trained to predict is itself a biased proxy for the true phenomenon of interest.
#
# **Why it matters:** Models typically predict "reported crime," "arrests," or "calls for service" rather than actual crime incidence. These labels are differentially generated: a robbery in a wealthy neighborhood is more likely to be called in, investigated, and result in an arrest than an equivalent act in a neighborhood where residents distrust police or where police resources are thinner. If the label is "arrests" rather than "crimes," the model learns to predict enforcement intensity, not safety risk. This distinction—between *crime* and *detected crime*—is foundational to understanding algorithmic bias in criminal justice (Lum and Isaac, 2016, demonstrated this explicitly using drug use data in Oakland).
#
# **Confidence this is present:** High.
#
# #### 1.1.3 Feedback Loops (Performative Prediction)
#
# **What it is:** The model's predictions influence where police patrol, which generates more arrests in predicted locations, which are fed back as training data, which reinforces the original predictions in a self-amplifying cycle.
#
# **Why it matters:** This is arguably the most dangerous technical mechanism because it compounds over time. Even a model with modest initial bias can produce extreme disparities after several feedback cycles. Research by Ensign and colleagues (2018) formally modeled this dynamic and demonstrated that feedback loops in predictive policing can drive patrol allocation toward a fixed point that bears little relationship to underlying crime distribution. The system becomes, in effect, a self-fulfilling prophecy.
#
# **Confidence this is present:** High if the model's outputs are used to direct patrol resources and the resulting enforcement data is fed back into model retraining. This is

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **To:** City Council
# **From:** Independent Consultant
# **Date:** October 26, 2023
# **Subject:** Report on Predictive Policing System Disparities & Remediation Plan
#
# ---
#
# ### **Executive Summary**
#
# Our audit confirms the AI-based predictive policing system disproportionately targets minority neighborhoods. This disparity arises from a combination of **technical flaws** (biased training data, label bias, feedback loops) and **non-technical factors** (historical policing patterns, socio-economic confounders, deployment decisions). Left unaddressed, the system risks exacerbating inequality, eroding community trust, and violating civil rights. This report provides a causal analysis, a 12-month remediation plan, an independent audit protocol, a principled trade-off framework, and key questions for officials. **I recommend the council immediately suspend the system’s use for patrol decisions and initiate the proposed remediation plan.**
#
# ---
#
# ### **1. Causes of Disparity**
#
# #### **Technical Causes**
# - **Biased Training Data:** Historical crime data reflect over-policing of minority neighborhoods (e.g., higher arrest rates for low-level offenses), embedding past bias into predictions (*“garbage in, garbage out”*).
# - **Label Bias:** Using arrests or reported crimes as “crime” labels conflates crime prevalence with policing intensity. This is a well-documented source of bias (e.g., Lum & Isaac, 2016).
# - **Feedback Loops:** Predicted hotspots lead to more patrols, which generate more recorded incidents, reinforcing future predictions (a “self-fulfilling prophecy”).
# - **Deployment Decisions:** Thresholds for “high risk” may be set without fairness considerations, amplifying disparities.
#
# #### **Non-Technical Causes**
# - **Policing Practices:** Resource allocation, officer discretion, and community reporting rates differ across neighborhoods.
# - **Socio-Economic Confounders:** Poverty, density, and unemployment correlate with both minority status and some crime types—the system may proxy race via these variables.
# - **Vendor Contract & Oversight:** Lack of transparency in proprietary algorithms, absence of fairness constraints in procurement.
#
# ---
#
# ### **2. 12-Month Remediation Plan**
#
# | Priority | Action | Timeline | Resources Needed | Expected Impact on Disparity/Public Safety | Unintended Consequences/Risks |
# |----------|--------|----------|------------------|--------------------------------------------|-------------------------------|
# | **1. Immediate Safeguards** | Suspend system for patrol allocation; retain for internal analysis only. | Week 1 | Legal review, IT patch. | Halts amplification of bias; short-term uncertainty in patrol planning. | Officer pushback; potential temporary rise in response times. |
# | **2. Data & Model Audit** | Commission independent audit of training data, labels, and model outputs (see Section 4). | Months 1–3 | $80K–$120K for auditors; data engineer (city staff). | Identifies specific bias sources; informs model redesign. | Vendor resistance; may reveal deeper systemic biases. |
# | **3. Community Engagement** | Form oversight board with community reps, public defenders, civil rights advocates. | Months 1–12 (ongoing) | 0.5 FTE coordinator; stipends for community members. | Builds trust, ensures accountability, informs fairness criteria. | Board may lack technical expertise; potential for divisiveness. |
# | **4. Model & Process Redesign** | Redesign system with fairness constraints (e.g., demographic parity, equalized FPR), use alternative data (e.g., 911 calls only), and implement “fairness through awareness” (Dwork et al., 2012). | Months 4–9 | Data scientists (2 FTE), vendor renegotiation ($150K–$300K). | Reduces disparity; may slightly reduce accuracy for majority groups. | Trade-offs between fairness/accuracy; requires careful validation. |
# | **5. Policy & Contract Changes** | Update procurement to require fairness reports, transparency, and city ownership of data/models. | Months 6–12 | Legal, procurement staff. | Prevents future vendor lock-in and black-box systems. | Higher upfront costs; vendors may resist. |
# | **6. Pilot & Monitor** | Pilot revised system in limited districts with pre-specified fairness thresholds. | Months 10–12 | Patrol coordination, monitoring team. | Allows real-world testing of fairness/accuracy trade-offs. | Possible community skepticism even with improvements. |
#
# ---
#
# ### **3. Action Details & Confidence**
#
# - **Immediate Suspension:** *High confidence* based on precedent (e.g., NYPD’s early predictive policing issues). Key uncertainty: contractual penalties with vendor.
# - **Independent Audit:** *High confidence*; necessary for diagnosing specific bias. Uncertainty: data accessibility.
# - **Community Oversight Board:** *Medium confidence*; critical for legitimacy, but effectiveness depends on representation and authority.
# - **Model Redesign:** *Medium confidence*; technical solutions exist but require careful implementation to avoid other harms.
#
# ---
#
# ### **4. Independent Audit Protocol**
#
# **Objective:** Detect disparate harms in predictions vs. outcomes.
#
# **Data Required:**
# - Model predictions (by location/demographic).
# - Ground-truth crime data (victimization surveys, 911 calls).
# - Patrol records (stops, arrests, use of force).
# - Demographic data (census, neighborhood composition).
#
# **Statistical Tests:**
# - **Disparate Impact Ratio:** Compare prediction rates across racial groups.
# - **Error Rate Analysis:** False positive/negative rates by group.
# - **Causal Tests:** Instrumental variables or difference-in-differences to assess feedback loops.
#
# **Acceptable Thresholds:**
# - 80% rule (disparate impact ratio ≥0.8) for initial screening.
# - Statistical significance (p<0.05) for error rate differences.
# - **Action Trigger:** Any violation requires mitigation before redeployment.
#
# **Auditor Independence:**
# - Third-party selection by council + community board.
# - Full transparency: public report, code, and data (where privacy-safe).
#
# ---
#
# ### **5. Principled Trade-Off Framework**
#
# Council should adopt a **“Fairness, Accountability, and Transparency”** framework:
#
# 1. **Operationalize Fairness:** Choose a fairness metric (e.g., equalized false positive rates) based on community input and legal advice. Different definitions (e.g., demographic parity vs. equalized odds) have different trade-offs (Kleinberg et al., 2017).
# 2. **Accept Accuracy Reductions:** If needed, prioritize reducing disparities over marginal gains in overall prediction accuracy. Precedent: Berkeley’s dropped predictive policing due to equity concerns.
# 3. **Monitor Outcomes:** Track both crime rates and community trust metrics (surveys, complaint rates). Use control districts without the system for comparison.
# 4. **Decision Rule:** System redeployment only if it meets pre-agreed fairness thresholds and does not increase disproportionate stops/arrests.
#
# ---
#
# ### **6. Top Five Factual Questions for City/Vendor**
#
# 1. **“What specific crime data and labels were used to train the model?”**
#    - *If arrest data only:* Urgent need to switch to victimization data.
#    - *If mixed sources:* Audit label definitions for bias.
#
# 2. **“How are model predictions translated into patrol decisions (thresholds, human override)?”**
#    - *If fully automated:* Immediate need for human-in-the-loop.
#    - *If discretionary:* Assess officer training and guidelines.
#
# 3. **“What fairness tests were conducted before deployment, and what disparities were found?”**
#    - *If none:* Indicates vendor negligence; consider contract termination.
#    - *If tests showed disparities but were ignored:* Need policy changes to mandate fairness.
#
# 4. **“What is the contractual exit cost and data ownership status?”**
#    - *If high exit cost:* Phase out while developing in-house capacity.
#    - *If city owns data/model:* More flexibility for redesign.
#
# 5. **“What is the historical disparity in police stops/arrests by neighborhood, independent of the AI system?”**
#    - *If high:* System may be amplifying existing bias; need broader policing reform.
#    - *If low:* Suggests technical flaws dominate.
#
# ---
#
# ### **Recommendation**
#
# **The council should immediately suspend the system’s operational use, commission an independent audit, and establish a community oversight board.** These steps halt harm, diagnose root causes, and ensure community voice in remediation. The proposed 12-month plan balances urgency with feasibility, addressing both technical and systemic factors. Continuing without intervention risks legal liability, deepened distrust, and perpetuation of inequity.
#
# ---
# **Confidence:** High for immediate suspension and audit; medium for long-term redesign due to vendor and data uncertainties.
# **Citations:** Lum & Isaac (2016), Dwork et al. (2012), Kleinberg et al. (2017), Berk et al. (2021) on fairness trade-offs.

# %%
# !pip3 install -q -U google
# !pip3 install -q -U google-genai
# !pip3 uninstall google-generativeai google-api-core googleapis-common-protos google -y
# !pip3 install --upgrade google-genai
# from google import genai

# %%
# from google import genai
# # from google.colab import userdata

# # API_KEY = os.getenv('GEMINI_API_KEY')
# # client = genai.Client(api_key=API_KEY)
# client = genai.Client()
# response = client.models.generate_content(
#     model="gemini-3-flash-preview",
#     contents="Explain how AI works in a few words",
# )

# print(response.text)

# %%
# gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
# model_name = "gemini-3.0-flash"

# response = gemini.chat.completions.create(model=model_name, messages=messages)
# answer = response.choices[0].message.content

# display(Markdown(answer))
# competitors.append(model_name)
# answers.append(answer)

# %%
# # Optional: this example uses the native Google Gen AI SDK
# # In a notebook, install it with: %pip install google-genai
# # Then restart the kernel before rerunning this cell

# import os
# from google import genai
# from google.genai import types


# def generate():
#     client = genai.Client(
#         api_key=os.environ.get("GOOGLE_API_KEY"),
#     )

#     model = "gemini-3-flash-preview"
#     contents = [
#         types.Content(
#             role="user",
#             parts=[
#                 types.Part.from_text(text="""INSERT_INPUT_HERE"""),
#             ],
#         ),
#     ]
#     tools = [
#         types.Tool(googleSearch=types.GoogleSearch(
#         )),
#     ]
#     generate_content_config = types.GenerateContentConfig(
#         thinking_config=types.ThinkingConfig(
#             thinking_level="HIGH",
#         ),
#         tools=tools,
#     )

#     for chunk in client.models.generate_content_stream(
#         model=model,
#         contents=contents,
#         config=generate_content_config,
#     ):
#         print(chunk.text, end="")

# if __name__ == "__main__":
#     generate()

# %%
# # Updated with the latest Open Source model from OpenAI

# groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
# model_name = "openai/gpt-oss-120b"

# response = groq.chat.completions.create(model=model_name, messages=messages)
# answer = response.choices[0].message.content

# display(Markdown(answer))
# competitors.append(model_name)
# answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 203 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 1.5 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 2.8 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 3.1 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 3.8 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 5.1 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 5.8 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 7.1 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 7.9 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 8.2 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 9.5 MB/2.0 GB  9.3 MB/s   3m35spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  10 MB/2.0 GB  9.3 MB/s   3m35spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  11 MB/2.0 GB  9.3 MB/s   3m35spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  12 MB/2.0 GB  9.3 MB/s   3m35spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  13 MB/2.0 GB  9.3 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  13 MB/2.0 GB  9.3 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  15 MB/2.0 GB  9.3 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  16 MB/2.0 GB  9.3 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  16 MB/2.0 GB  9.3 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  16 MB/2.0 GB  9.3 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  17 MB/2.0 GB  8.8 MB/s   3m47spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  18 MB/2.0 GB  8.8 MB/s   3m47spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  19 MB/2.0 GB  8.8 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  21 MB/2.0 GB  8.8 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  21 MB/2.0 GB  8.8 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  22 MB/2.0 GB  8.8 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  23 MB/2.0 GB  8.8 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  24 MB/2.0 GB  8.8 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  25 MB/2.0 GB  8.8 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  26 MB/2.0 GB  8.8 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  26 MB/2.0 GB  8.8 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  27 MB/2.0 GB  9.0 MB/s   3m40spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  29 MB/2.0 GB  9.0 MB/s   3m40spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  29 MB/2.0 GB  9.0 MB/s   3m40spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  31 MB/2.0 GB  9.0 MB/s   3m40spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  31 MB/2.0 GB  9.0 MB/s   3m40spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  32 MB/2.0 GB  9.0 MB/s   3m39spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  33 MB/2.0 GB  9.0 MB/s   3m39spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  35 MB/2.0 GB  9.0 MB/s   3m39spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  35 MB/2.0 GB  9.0 MB/s   3m39spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  36 MB/2.0 GB  9.0 MB/s   3m39spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  37 MB/2.0 GB  9.1 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  38 MB/2.0 GB  9.1 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  39 MB/2.0 GB  9.1 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  40 MB/2.0 GB  9.1 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  41 MB/2.0 GB  9.1 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  41 MB/2.0 GB  9.1 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  43 MB/2.0 GB  9.1 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  43 MB/2.0 GB  9.1 MB/s   3m36spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  45 MB/2.0 GB  9.1 MB/s   3m35spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  45 MB/2.0 GB  9.1 MB/s   3m35spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  46 MB/2.0 GB  9.2 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  47 MB/2.0 GB  9.2 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  48 MB/2.0 GB  9.2 MB/s   3m33spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  49 MB/2.0 GB  9.2 MB/s   3m33spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  50 MB/2.0 GB  9.2 MB/s   3m33spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  51 MB/2.0 GB  9.2 MB/s   3m33spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  51 MB/2.0 GB  9.2 MB/s   3m33spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  52 MB/2.0 GB  9.2 MB/s   3m33spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  53 MB/2.0 GB  9.2 MB/s   3m33spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  53 MB/2.0 GB  9.2 MB/s   3m33spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  53 MB/2.0 GB  8.8 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  53 MB/2.0 GB  8.8 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  53 MB/2.0 GB  8.8 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  54 MB/2.0 GB  8.8 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  56 MB/2.0 GB  8.8 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  56 MB/2.0 GB  8.8 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  56 MB/2.0 GB  8.8 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  57 MB/2.0 GB  8.8 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  57 MB/2.0 GB  8.8 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  58 MB/2.0 GB  8.8 MB/s   3m42spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  58 MB/2.0 GB  8.4 MB/s   3m54spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  59 MB/2.0 GB  8.4 MB/s   3m54spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  59 MB/2.0 GB  8.4 MB/s   3m54spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  60 MB/2.0 GB  8.4 MB/s   3m54spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  60 MB/2.0 GB  8.4 MB/s   3m54spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  62 MB/2.0 GB  8.4 MB/s   3m54spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  62 MB/2.0 GB  8.4 MB/s   3m54spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  62 MB/2.0 GB  8.4 MB/s   3m54spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  63 MB/2.0 GB  8.4 MB/s   3m54spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  63 MB/2.0 GB  8.4 MB/s   3m54spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  63 MB/2.0 GB  8.4 MB/s   3m54spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  64 MB/2.0 GB  8.0 MB/s    4m5spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  64 MB/2.0 GB  8.0 MB/s    4m5spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  64 MB/2.0 GB  8.0 MB/s    4m5spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  65 MB/2.0 GB  8.0 MB/s    4m5spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  67 MB/2.0 GB  8.0 MB/s    4m4spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  67 MB/2.0 GB  8.0 MB/s    4m4spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  67 MB/2.0 GB  8.0 MB/s    4m4spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  67 MB/2.0 GB  8.0 MB/s    4m4spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  68 MB/2.0 GB  8.0 MB/s    4m4spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  68 MB/2.0 GB  8.0 MB/s    4m4spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  69 MB/2.0 GB  7.7 MB/s   4m14spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  69 MB/2.0 GB  7.7 MB/s   4m14spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  69 MB/2.0 GB  7.7 MB/s   4m14spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  70 MB/2.0 GB  7.7 MB/s   4m14spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  71 MB/2.0 GB  7.7 MB/s   4m14spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  72 MB/2.0 GB  7.7 MB/s   4m14spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  73 MB/2.0 GB  7.7 MB/s   4m14spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  73 MB/2.0 GB  7.7 MB/s   4m14spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  73 MB/2.0 GB  7.7 MB/s   4m13spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  73 MB/2.0 GB  7.7 MB/s   4m13spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  74 MB/2.0 GB  7.2 MB/s   4m30spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  74 MB/2.0 GB  7.2 MB/s   4m30spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  75 MB/2.0 GB  7.2 MB/s   4m30spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  75 MB/2.0 GB  7.2 MB/s   4m30spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  76 MB/2.0 GB  7.2 MB/s   4m30spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  77 MB/2.0 GB  7.2 MB/s   4m30spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  77 MB/2.0 GB  7.2 MB/s   4m30spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  78 MB/2.0 GB  7.2 MB/s   4m30spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  78 MB/2.0 GB  7.2 MB/s   4m29spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  78 MB/2.0 GB  7.2 MB/s   4m29spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  78 MB/2.0 GB  6.8 MB/s   4m45spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  79 MB/2.0 GB  6.8 MB/s   4m45spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  80 MB/2.0 GB  6.8 MB/s   4m45spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  81 MB/2.0 GB  6.8 MB/s   4m45spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  82 MB/2.0 GB  6.8 MB/s   4m44spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  83 MB/2.0 GB  6.8 MB/s   4m44spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  84 MB/2.0 GB  6.8 MB/s   4m44spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  85 MB/2.0 GB  6.8 MB/s   4m44spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  85 MB/2.0 GB  6.8 MB/s   4m44spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  87 MB/2.0 GB  6.8 MB/s   4m44spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  88 MB/2.0 GB  6.8 MB/s   4m44spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  89 MB/2.0 GB  6.9 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  89 MB/2.0 GB  6.9 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  90 MB/2.0 GB  6.9 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  90 MB/2.0 GB  6.9 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  91 MB/2.0 GB  6.9 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  92 MB/2.0 GB  6.9 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  92 MB/2.0 GB  6.9 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  92 MB/2.0 GB  6.9 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  94 MB/2.0 GB  6.9 MB/s   4m39spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  94 MB/2.0 GB  6.9 MB/s   4m38spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  96 MB/2.0 GB  6.6 MB/s   4m50spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  96 MB/2.0 GB  6.6 MB/s   4m50spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  97 MB/2.0 GB  6.6 MB/s   4m50spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  98 MB/2.0 GB  6.6 MB/s   4m50spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 100 MB/2.0 GB  6.6 MB/s   4m50spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 100 MB/2.0 GB  6.6 MB/s   4m50spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 101 MB/2.0 GB  6.6 MB/s   4m49spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 102 MB/2.0 GB  6.6 MB/s   4m49spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 103 MB/2.0 GB  6.6 MB/s   4m49spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 104 MB/2.0 GB  6.6 MB/s   4m49spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 105 MB/2.0 GB  6.6 MB/s   4m49spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 106 MB/2.0 GB  6.6 MB/s   4m49spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 106 MB/2.0 GB  6.6 MB/s   4m48spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 108 MB/2.0 GB  6.6 MB/s   4m48spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 108 MB/2.0 GB  6.6 MB/s   4m48spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 110 MB/2.0 GB  6.6 MB/s   4m48spulling manifest
# pulling dde5aa3fc5ff:   6% ▕                  ▏ 111 MB/2.0 GB  6.6 MB/s   4m48spulling manifest
# pulling dde5aa3fc5ff:   6% ▕                  ▏ 111 MB/2.0 GB  6.6 MB/s   4m48spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 112 MB/2.0 GB  6.6 MB/s   4m48spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 113 MB/2.0 GB  6.6 MB/s   4m47spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 114 MB/2.0 GB  6.6 MB/s   4m47spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 115 MB/2.0 GB  6.9 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 116 MB/2.0 GB  6.9 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 117 MB/2.0 GB  6.9 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 118 MB/2.0 GB  6.9 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 119 MB/2.0 GB  6.9 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 120 MB/2.0 GB  6.9 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 121 MB/2.0 GB  6.9 MB/s   4m35spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 122 MB/2.0 GB  6.9 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 122 MB/2.0 GB  6.9 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 124 MB/2.0 GB  6.9 MB/s   4m34spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 125 MB/2.0 GB  7.3 MB/s   4m17spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 126 MB/2.0 GB  7.3 MB/s   4m17spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 126 MB/2.0 GB  7.3 MB/s   4m17spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 127 MB/2.0 GB  7.3 MB/s   4m17spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 128 MB/2.0 GB  7.3 MB/s   4m17spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 129 MB/2.0 GB  7.3 MB/s   4m17spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 130 MB/2.0 GB  7.3 MB/s   4m17spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 131 MB/2.0 GB  7.3 MB/s   4m16spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 132 MB/2.0 GB  7.3 MB/s   4m16spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 133 MB/2.0 GB  7.3 MB/s   4m16spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 134 MB/2.0 GB  7.8 MB/s    4m1spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 135 MB/2.0 GB  7.8 MB/s    4m1spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 136 MB/2.0 GB  7.8 MB/s    4m1spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 136 MB/2.0 GB  7.8 MB/s    4m1spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 137 MB/2.0 GB  7.8 MB/s    4m0spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 139 MB/2.0 GB  7.8 MB/s    4m0spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 139 MB/2.0 GB  7.8 MB/s    4m0spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 140 MB/2.0 GB  7.8 MB/s    4m0spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 141 MB/2.0 GB  7.8 MB/s    4m0spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 142 MB/2.0 GB  7.8 MB/s    4m0spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 143 MB/2.0 GB  8.3 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 144 MB/2.0 GB  8.3 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 145 MB/2.0 GB  8.3 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 145 MB/2.0 GB  8.3 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 146 MB/2.0 GB  8.3 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 147 MB/2.0 GB  8.3 MB/s   3m46spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 148 MB/2.0 GB  8.3 MB/s   3m45spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 149 MB/2.0 GB  8.3 MB/s   3m45spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 149 MB/2.0 GB  8.3 MB/s   3m45spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 150 MB/2.0 GB  8.3 MB/s   3m45spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 152 MB/2.0 GB  8.7 MB/s   3m35spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 152 MB/2.0 GB  8.7 MB/s   3m35spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 154 MB/2.0 GB  8.7 MB/s   3m35spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 154 MB/2.0 GB  8.7 MB/s   3m35spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 155 MB/2.0 GB  8.7 MB/s   3m35spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 156 MB/2.0 GB  8.7 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 157 MB/2.0 GB  8.7 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 158 MB/2.0 GB  8.7 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 159 MB/2.0 GB  8.7 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 159 MB/2.0 GB  8.7 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 159 MB/2.0 GB  8.7 MB/s   3m34spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 160 MB/2.0 GB  9.0 MB/s   3m26spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 161 MB/2.0 GB  9.0 MB/s   3m26spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 162 MB/2.0 GB  9.0 MB/s   3m26spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 162 MB/2.0 GB  9.0 MB/s   3m26spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 163 MB/2.0 GB  9.0 MB/s   3m26spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 164 MB/2.0 GB  9.0 MB/s   3m26spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 165 MB/2.0 GB  9.0 MB/s   3m26spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 166 MB/2.0 GB  9.0 MB/s   3m25spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 166 MB/2.0 GB  9.0 MB/s   3m25spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 168 MB/2.0 GB  9.0 MB/s   3m25spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 169 MB/2.0 GB  8.8 MB/s   3m29spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 170 MB/2.0 GB  8.8 MB/s   3m29spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 171 MB/2.0 GB  8.8 MB/s   3m29spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 171 MB/2.0 GB  8.8 MB/s   3m29spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 172 MB/2.0 GB  8.8 MB/s   3m29spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 173 MB/2.0 GB  8.8 MB/s   3m29spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 174 MB/2.0 GB  8.8 MB/s   3m28spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 175 MB/2.0 GB  8.8 MB/s   3m28spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 176 MB/2.0 GB  8.8 MB/s   3m28spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 177 MB/2.0 GB  8.8 MB/s   3m28spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 177 MB/2.0 GB  9.1 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 179 MB/2.0 GB  9.1 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 180 MB/2.0 GB  9.1 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 181 MB/2.0 GB  9.1 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 181 MB/2.0 GB  9.1 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 182 MB/2.0 GB  9.1 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 183 MB/2.0 GB  9.1 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 184 MB/2.0 GB  9.1 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 186 MB/2.0 GB  9.1 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 186 MB/2.0 GB  9.1 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 187 MB/2.0 GB  9.1 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 188 MB/2.0 GB  9.1 MB/s   3m21spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 189 MB/2.0 GB  9.1 MB/s   3m21spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 190 MB/2.0 GB  9.1 MB/s   3m21spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 191 MB/2.0 GB  9.1 MB/s   3m21spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 191 MB/2.0 GB  9.1 MB/s   3m21spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 193 MB/2.0 GB  9.1 MB/s   3m21spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 194 MB/2.0 GB  9.1 MB/s   3m21spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 195 MB/2.0 GB  9.1 MB/s   3m21spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 196 MB/2.0 GB  9.1 MB/s   3m21spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 196 MB/2.0 GB  9.1 MB/s   3m21spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 197 MB/2.0 GB  9.1 MB/s   3m20spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 198 MB/2.0 GB  9.1 MB/s   3m20spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 200 MB/2.0 GB  9.1 MB/s   3m20spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 200 MB/2.0 GB  9.1 MB/s   3m20spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 201 MB/2.0 GB  9.1 MB/s   3m20spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 201 MB/2.0 GB  9.1 MB/s   3m20spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 203 MB/2.0 GB  9.1 MB/s   3m20spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 204 MB/2.0 GB  9.1 MB/s   3m20spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 205 MB/2.0 GB  9.1 MB/s   3m20spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 205 MB/2.0 GB  9.1 MB/s   3m20spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 206 MB/2.0 GB  9.1 MB/s   3m20spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 208 MB/2.0 GB  9.1 MB/s   3m20spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 208 MB/2.0 GB  9.1 MB/s   3m19spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 210 MB/2.0 GB  9.1 MB/s   3m19spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 210 MB/2.0 GB  9.1 MB/s   3m19spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 211 MB/2.0 GB  9.1 MB/s   3m19spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 212 MB/2.0 GB  9.1 MB/s   3m19spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 214 MB/2.0 GB  9.1 MB/s   3m19spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 214 MB/2.0 GB  9.1 MB/s   3m19spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 215 MB/2.0 GB  9.1 MB/s   3m19spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 216 MB/2.0 GB  9.1 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 217 MB/2.0 GB  9.1 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 218 MB/2.0 GB  9.1 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 219 MB/2.0 GB  9.1 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 219 MB/2.0 GB  9.1 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 219 MB/2.0 GB  9.1 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 220 MB/2.0 GB  9.1 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 220 MB/2.0 GB  9.1 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 222 MB/2.0 GB  9.1 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 223 MB/2.0 GB  9.1 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 223 MB/2.0 GB  8.8 MB/s   3m23spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 224 MB/2.0 GB  8.8 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 225 MB/2.0 GB  8.8 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 226 MB/2.0 GB  8.8 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 227 MB/2.0 GB  8.8 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 228 MB/2.0 GB  8.8 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 228 MB/2.0 GB  8.8 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 230 MB/2.0 GB  8.8 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 231 MB/2.0 GB  8.8 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 232 MB/2.0 GB  8.8 MB/s   3m22spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 233 MB/2.0 GB  9.0 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 234 MB/2.0 GB  9.0 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 234 MB/2.0 GB  9.0 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 235 MB/2.0 GB  9.0 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 236 MB/2.0 GB  9.0 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 237 MB/2.0 GB  9.0 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 237 MB/2.0 GB  9.0 MB/s   3m18spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 239 MB/2.0 GB  9.0 MB/s   3m17spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 239 MB/2.0 GB  9.0 MB/s   3m17spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 241 MB/2.0 GB  9.0 MB/s   3m17spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 242 MB/2.0 GB  9.2 MB/s   3m13spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 242 MB/2.0 GB  9.2 MB/s   3m13spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 243 MB/2.0 GB  9.2 MB/s   3m13spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 245 MB/2.0 GB  9.2 MB/s   3m13spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 245 MB/2.0 GB  9.2 MB/s   3m13spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 247 MB/2.0 GB  9.2 MB/s   3m13spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 247 MB/2.0 GB  9.2 MB/s   3m13spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 248 MB/2.0 GB  9.2 MB/s   3m13spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 249 MB/2.0 GB  9.2 MB/s   3m13spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 250 MB/2.0 GB  9.2 MB/s   3m12spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 251 MB/2.0 GB  9.2 MB/s   3m12spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 252 MB/2.0 GB  9.3 MB/s   3m11spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 253 MB/2.0 GB  9.3 MB/s   3m10spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 253 MB/2.0 GB  9.3 MB/s   3m10spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 255 MB/2.0 GB  9.3 MB/s   3m10spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 256 MB/2.0 GB  9.3 MB/s   3m10spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 257 MB/2.0 GB  9.3 MB/s   3m10spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 257 MB/2.0 GB  9.3 MB/s   3m10spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 258 MB/2.0 GB  9.3 MB/s   3m10spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 259 MB/2.0 GB  9.3 MB/s   3m10spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 260 MB/2.0 GB  9.3 MB/s   3m10spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 261 MB/2.0 GB  9.3 MB/s    3m9spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 261 MB/2.0 GB  9.3 MB/s    3m9spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 263 MB/2.0 GB  9.3 MB/s    3m9spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 264 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 265 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 266 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 267 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 267 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 269 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 270 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 271 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 271 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 272 MB/2.0 GB  9.3 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 273 MB/2.0 GB  9.3 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 274 MB/2.0 GB  9.3 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 276 MB/2.0 GB  9.3 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 276 MB/2.0 GB  9.3 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 277 MB/2.0 GB  9.3 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 278 MB/2.0 GB  9.3 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 279 MB/2.0 GB  9.3 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 280 MB/2.0 GB  9.3 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 281 MB/2.0 GB  9.3 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 281 MB/2.0 GB  9.3 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 283 MB/2.0 GB  9.3 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 284 MB/2.0 GB  9.3 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 285 MB/2.0 GB  9.3 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 286 MB/2.0 GB  9.3 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 286 MB/2.0 GB  9.3 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 287 MB/2.0 GB  9.3 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 288 MB/2.0 GB  9.3 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 290 MB/2.0 GB  9.3 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 290 MB/2.0 GB  9.3 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 291 MB/2.0 GB  9.3 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 292 MB/2.0 GB  9.3 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 292 MB/2.0 GB  9.3 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 293 MB/2.0 GB  9.3 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 295 MB/2.0 GB  9.3 MB/s    3m4spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 295 MB/2.0 GB  9.3 MB/s    3m4spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 296 MB/2.0 GB  9.3 MB/s    3m4spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 297 MB/2.0 GB  9.3 MB/s    3m4spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 298 MB/2.0 GB  9.3 MB/s    3m4spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 299 MB/2.0 GB  9.2 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 300 MB/2.0 GB  9.2 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 300 MB/2.0 GB  9.2 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 301 MB/2.0 GB  9.2 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 303 MB/2.0 GB  9.2 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 303 MB/2.0 GB  9.2 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 305 MB/2.0 GB  9.2 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 305 MB/2.0 GB  9.2 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 306 MB/2.0 GB  9.2 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 307 MB/2.0 GB  9.2 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 309 MB/2.0 GB  9.5 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 309 MB/2.0 GB  9.5 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 310 MB/2.0 GB  9.5 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 311 MB/2.0 GB  9.5 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 312 MB/2.0 GB  9.5 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 313 MB/2.0 GB  9.5 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 314 MB/2.0 GB  9.5 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 315 MB/2.0 GB  9.5 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 315 MB/2.0 GB  9.5 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 317 MB/2.0 GB  9.5 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 317 MB/2.0 GB  9.4 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 318 MB/2.0 GB  9.4 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 319 MB/2.0 GB  9.4 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 319 MB/2.0 GB  9.4 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 321 MB/2.0 GB  9.4 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 322 MB/2.0 GB  9.4 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 323 MB/2.0 GB  9.4 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 324 MB/2.0 GB  9.4 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 325 MB/2.0 GB  9.4 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 325 MB/2.0 GB  9.4 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 327 MB/2.0 GB  9.4 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 328 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 329 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 329 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 330 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 331 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 332 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██                ▏ 334 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██                ▏ 334 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██                ▏ 335 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██                ▏ 336 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 337 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 338 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 339 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 339 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 340 MB/2.0 GB  9.4 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 342 MB/2.0 GB  9.4 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 342 MB/2.0 GB  9.4 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 344 MB/2.0 GB  9.4 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 344 MB/2.0 GB  9.4 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 345 MB/2.0 GB  9.4 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 346 MB/2.0 GB  9.4 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 348 MB/2.0 GB  9.4 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 348 MB/2.0 GB  9.4 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 349 MB/2.0 GB  9.4 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 350 MB/2.0 GB  9.4 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 351 MB/2.0 GB  9.4 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 352 MB/2.0 GB  9.4 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 353 MB/2.0 GB  9.4 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 354 MB/2.0 GB  9.4 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 354 MB/2.0 GB  9.4 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 356 MB/2.0 GB  9.4 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 356 MB/2.0 GB  9.4 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 358 MB/2.0 GB  9.4 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 359 MB/2.0 GB  9.4 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 359 MB/2.0 GB  9.4 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 360 MB/2.0 GB  9.4 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 361 MB/2.0 GB  9.4 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 362 MB/2.0 GB  9.4 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 363 MB/2.0 GB  9.4 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 364 MB/2.0 GB  9.4 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 364 MB/2.0 GB  9.3 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 366 MB/2.0 GB  9.3 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 367 MB/2.0 GB  9.3 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 368 MB/2.0 GB  9.3 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 368 MB/2.0 GB  9.3 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 369 MB/2.0 GB  9.3 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 370 MB/2.0 GB  9.3 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 371 MB/2.0 GB  9.3 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 373 MB/2.0 GB  9.3 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 373 MB/2.0 GB  9.3 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 374 MB/2.0 GB  9.3 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 375 MB/2.0 GB  9.3 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 376 MB/2.0 GB  9.3 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 377 MB/2.0 GB  9.3 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 378 MB/2.0 GB  9.3 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 378 MB/2.0 GB  9.3 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 379 MB/2.0 GB  9.3 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 381 MB/2.0 GB  9.3 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 381 MB/2.0 GB  9.3 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 383 MB/2.0 GB  9.3 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 383 MB/2.0 GB  9.4 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 384 MB/2.0 GB  9.4 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 385 MB/2.0 GB  9.4 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 386 MB/2.0 GB  9.4 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 387 MB/2.0 GB  9.4 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 388 MB/2.0 GB  9.4 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 389 MB/2.0 GB  9.4 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 389 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 391 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 392 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 392 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 393 MB/2.0 GB  9.4 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 394 MB/2.0 GB  9.4 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 395 MB/2.0 GB  9.4 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 396 MB/2.0 GB  9.4 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 397 MB/2.0 GB  9.4 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 397 MB/2.0 GB  9.4 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 398 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 400 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 400 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 402 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 402 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 403 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 404 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 405 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 406 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 406 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 407 MB/2.0 GB  9.4 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 408 MB/2.0 GB  9.4 MB/s   2m51spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 409 MB/2.0 GB  9.4 MB/s   2m51spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 411 MB/2.0 GB  9.4 MB/s   2m51spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 411 MB/2.0 GB  9.4 MB/s   2m51spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 412 MB/2.0 GB  9.4 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 413 MB/2.0 GB  9.4 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 414 MB/2.0 GB  9.4 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 415 MB/2.0 GB  9.4 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 416 MB/2.0 GB  9.4 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 416 MB/2.0 GB  9.4 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 418 MB/2.0 GB  9.4 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 419 MB/2.0 GB  9.4 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 420 MB/2.0 GB  9.4 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 421 MB/2.0 GB  9.4 MB/s   2m49spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 421 MB/2.0 GB  9.4 MB/s   2m49spulling manifest
# ...
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Report: Remediation Plan for AI‑Based Predictive Policing System**
#
# **I. Introduction**
#
# The city's AI-based predictive policing system has been shown to disproportionately target minority neighborhoods, raising concerns about systemic bias and potential harm to communities of color. This report aims to provide a comprehensive analysis of the plausible causes of the disparity and proposed a prioritized 12-month remediation plan to address these issues.
#
# **II. Causes of Disparity**
#
# Technical causes:
#
# 1. **Biased training data**: Inadequate or skewed training datasets can perpetuate existing biases.
# 2. **Label bias**: Labelling patterns in historical crime data may reflect discrimination against minority groups.
# 3. **Feedback loops**: The system's self-reinforcing nature can amplify biased assumptions and predictions.
#
# Non-technical causes:
#
# 1. **Policing practices**: Aggressive policing tactics, racial profiling, and over-policing of minority neighborhoods contribute to the disparity.
# 2. **Socio-economic confounders**: Systematic differences in poverty rates, education levels, and employment opportunities across neighborhoods can skew crime data.
# 3. **Deployment decisions**: The system's algorithms are deployed without adequate consideration for community context, exacerbating biases.
#
# **III. Remediation Plan**
#
# A. Immediate Safeguards (Months 1-3)
#
# 1. **Data audit**: Conduct a thorough review of training data to identify patterns and biases (Estimated impact on disparity: −20%).
# 2. **System auditing**: Perform regular checks for updates, anomalies, and bias-related issues.
# 3. **Community outreach**: Engage in community forums to raise awareness and establish a dialogue on AI-based policing.
#
# B. Data and Model Updates (Months 4-6)
#
# 1. **Model adjustments**: Implement data-driven updates to reduce bias in algorithms ($100,000 - $300,000).
# 2. **Training dataset refresh**: Regularly update training datasets to reflect changing community demographics.
# 3. **External validation**: Engage with independent experts for model testing and validation.
#
# C. Deployment and Decision-Making Changes (Months 7-9)
#
# 1. **Algorithmic adjustments**: Implement algorithms that prioritize contextual understanding over simplistic rules ($150,000 - $400,000).
# 2. **Deployment guidelines**: Develop and deploy guidelines to address potential biases in deployment decisions.
# 3. **Training for officers**: Provide training on AI-based policing tools and their limitations.
#
# D. Community Engagement and Oversight (Months 10-12)
#
# 1. **Community advisory board**: Establish an independent community board to monitor the system's performance.
# 2. **Regular audits**: Perform quarterly audits to assess disparities and adjust mitigation strategies as needed.
# 3. **Policy oversight**: Conduct regular review of policy changes aligning with community feedback and expert input.
#
# E. Policy and Contractual Changes (Months 12-18)
#
# 1. **Racial bias policy**: Develop a city-wide policy on AI-based policing, emphasizing fairness and equity ($200,000 - $500,000).
# 2. **Vendor contract reviews**: Conduct regular reviews of contracts with vendors to ensure compliance with bias mitigation measures.
# 3. **Transparency reporting**: Establish clear reporting guidelines for transparency regarding the system's performance.
#
# **IV. Independent Audit Protocol**
#
# A. Data Collection:
#
# 1. Disaggregate crime data by neighborhood type and demographic groupings.
# 2. Analyze deployment patterns, response rates, and outcomes (e.g., arrests, convictions).
#
# B. Statistical and Causal Tests:
#
# 1. Apply regression analysis to assess disparities in historical crime data.
# 2. Employ causality tests to determine whether algorithmic predictions lead to distinct changes in policing behaviors.
#
# C. Acceptable Thresholds for Action:
#
# 1. Establish benchmarks for disparity reduction targets (e.g., 15%); adjust these as necessary.
# 2. Engage with local experts and civil society organizations to set thresholds for bias recognition.
#
# D. Auditor Independence and Transparency
#
# 1. Ensure the independent auditor has no direct affiliation with vendors or internal stakeholders.
# 2. Implement a structured process for sharing findings, recommendations, and system evaluation data with relevant city departments, community boards, and external stakeholders.
#
# **V. Principles for Tradeoff Between Predictive Accuracy, Public Safety, and Civil-Rights Protections**
#
# To balance predictive accuracy, public safety, and civil-rights protections:
#
# 1. **Data-driven decision-making**: Leverage objective data to underpin policing decisions.
# 2. **Algorithmic explainability**: Ensure algorithms provide robust explanations for recommendations.
# 3. **Community-centric approaches**: Prioritize contextual understanding and feedback from affected communities.
#
# These core principles inform adjustments in model deployment, decision-making processes, and ongoing community engagement throughout the project timeline.
#
# **VI. Top Five Questions to Ask City Officials or Vendors**
#
# 1. What data sources were used to develop the predictive policing system?
# 2. How has the system been validated against diverse training datasets, including samples representing minority populations?
#
# **VII. Conclusion and Confidence Level**
#
# This report emphasizes a 12-month remediation plan focused on immediate safeguards, ongoing audits, strategic software updates, deployment changes, and community oversight. To ensure our recommendations are effective, I set high confidence levels across most measures. However, uncertainties related to data availability, model explanations, vendor compliance with regulations, and societal perceptions of AI must be addressed.
#
# The best path forward is that the council engages in this collaborative framework with local stakeholders to identify specific questions and address emerging concerns.
#
# We recommend:
#
# 1. The city implement these measures to address disparity.
# 2. Regular community engagement ensures buy-in for systemic improvements.
#
# These priorities will allow the system to improve its performance and prioritize protection over prediction

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'claude-sonnet-4-6', 'deepseek-chat', 'llama3.2']
# ['Council-ready report: Addressing disparities in an AI-based predictive policing system\n\nDate: [Insert date]\n\nExecutive summary\n- Problem: An AI-driven predictive policing system is disproportionately flagging minority neighborhoods, raising civil-rights concerns and eroding public trust.\n- Core finding: Disparities arise from a mix of technical causes (biased historical data, label bias, feedback loops, feature leakage, data quality gaps) and non-technical causes (policing practices, deployment choices, socio-economic confounders, governance and contractor practices).\n- Plan: A 12-month remediation program combining immediate safeguards, data/model audits, deployment/process changes, community oversight, and binding vendor policy changes; plus an independent audit protocol and a principled framework to balance accuracy, public safety, and civil rights.\n- Outcome sought: Reduced bias in predictions while preserving or improving public safety, with transparent, auditable processes and robust community oversight.\n\n1) Plausible causes of disparity: technical vs. non-technical\nA. Technical causes\n- Biased training data\n  - Historical policing records reflect prior enforcement biases (e.g., over-policing in minority neighborhoods), creating biased predictive signals.\n- Label bias\n  - The target variable (crime labels, arrests, gun detections) may reflect enforcement practices and not true underlying risk, injecting label bias.\n- Feedback loops\n  - Predicted risk drives policing activity in certain areas, generating more incident data there and reinforcing the model’s belief that those areas are high risk (self-fulfilling loop).\n- Data quality and representation gaps\n  - Missing data, under-reporting in some communities, or insufficient coverage of certain geographies skew model training.\n- Feature biases and leakage\n  - Proximity to police facilities, prior stop frequencies, or census-geography proxies can act as proxies for sensitive attributes; models may learn spurious correlations with protected groups.\n- Model design choices\n  - Complexity or training procedures that optimize overall accuracy at the expense of fairness; failure to calibrate scores across groups.\n- Temporal drift and nonstationarity\n  - Crime patterns shift; models trained on older data misrepresent current risk, potentially differentially affecting groups.\nB. Non-technical causes\n- Policing practices and policy\n  - Law enforcement priorities, discretionary stops, or geofenced deployment that concentrate effort in particular neighborhoods.\n- Deployment decisions and governance\n  - Where and how predictions influence action (e.g., early-warning flags vs. reactive discretion) shapes how disparities translate into outcomes.\n- Socio-economic confounders\n  - Structural inequalities (poverty, housing, education, limited legitimate opportunities) correlate with crime metrics and neighborhood demographics, confounding causal interpretation.\n- Vendor and procurement factors\n  - Contracts that emphasize predictive accuracy without fairness requirements; opaque model provenance; lack of independent audits.\n- Community trust and data sharing\n  - Under-resourced communities may have lower engagement or reporting rates, affecting data representativeness.\n\nNotes on causality and interpretation\n- Many causes are interdependent. For example, biased training data + feedback loops + policing deployment choices can magnify disparities even when the underlying model is technically well-behaved.\n- Distinguishing between short-term remediation (e.g., threshold re-calibration) and long-term systemic reform (e.g., governance reforms, data collection improvements) is essential.\n\n2) A prioritized, feasible 12-month remediation plan\nGuiding principles\n- Immediate safeguards first: ensure human review, prohibit automatic discretionary actions based solely on risk scores, and place a cap on high-stakes decisions driven by the model.\n- Data and m ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# Council-ready report: Addressing disparities in an AI-based predictive policing system
#
# Date: [Insert date]
#
# Executive summary
# - Problem: An AI-driven predictive policing system is disproportionately flagging minority neighborhoods, raising civil-rights concerns and eroding public trust.
# - Core finding: Disparities arise from a mix of technical causes (biased historical data, label bias, feedback loops, feature leakage, data quality gaps) and non-technical causes (policing practices, deployment choices, socio-economic confounders, governance and contractor practices).
# - Plan: A 12-month remediation program combining immediate safeguards, data/model audits, deployment/process changes, community oversight, and binding vendor policy changes; plus an independent audit protocol and a principled framework to balance accuracy, public safety, and civil rights.
# - Outcome sought: Reduced bias in predictions while preserving or improving public safety, with transparent, auditable processes and robust community oversight.
#
# 1) Plausible causes of disparity: technical vs. non-technical
# A. Technical causes
# - Biased training data
#   - Historical policing records reflect prior enforcement biases (e.g., over-policing in minority neighborhoods), creating biased predictive signals.
# - Label bias
#   - The target variable (crime labels, arrests, gun detections) may reflect enforcement practices and not true underlying risk, injecting label bias.
# - Feedback loops
#   - Predicted risk drives policing activity in certain areas, generating more incident data there and reinforcing the model’s belief that those areas are high risk (self-fulfilling loop).
# - Data quality and representation gaps
#   - Missing data, under-reporting in some communities, or insufficient coverage of certain geographies skew model training.
# - Feature biases and leakage
#   - Proximity to police facilities, prior stop frequencies, or census-geography proxies can act as proxies for sensitive attributes; models may learn spurious correlations with protected groups.
# - Model design choices
#   - Complexity or training procedures that optimize overall accuracy at the expense of fairness; failure to calibrate scores across groups.
# - Temporal drift and nonstationarity
#   - Crime patterns shift; models trained on older data misrepresent current risk, potentially differentially affecting groups.
# B. Non-technical causes
# - Policing practices and policy
#   - Law enforcement priorities, discretionary stops, or geofenced deployment that concentrate effort in particular neighborhoods.
# - Deployment decisions and governance
#   - Where and how predictions influence action (e.g., early-warning flags vs. reactive discretion) shapes how disparities translate into outcomes.
# - Socio-economic confounders
#   - Structural inequalities (poverty, housing, education, limited legitimate opportunities) correlate with crime metrics and neighborhood demographics, confounding causal interpretation.
# - Vendor and procurement factors
#   - Contracts that emphasize predictive accuracy without fairness requirements; opaque model provenance; lack of independent audits.
# - Community trust and data sharing
#   - Under-resourced communities may have lower engagement or reporting rates, affecting data representativeness.
#
# Notes on causality and interpretation
# - Many causes are interdependent. For example, biased training data + feedback loops + policing deployment choices can magnify disparities even when the underlying model is technically well-behaved.
# - Distinguishing between short-term remediation (e.g., threshold re-calibration) and long-term systemic reform (e.g., governance reforms, data collection improvements) is essential.
#
# 2) A prioritized, feasible 12-month remediation plan
# Guiding principles
# - Immediate safeguards first: ensure human review, prohibit automatic discretionary actions based solely on risk scores, and place a cap on high-stakes decisions driven by the model.
# - Data and model transparency: audits, audits, audits—internal and independent.
# - Community oversight: establish protections and channels for affected communities; publish aggregate metrics and progress.
# - Vendor accountability: contractually bind fairness, transparency, and audit rights.
#
# 12-month plan (action-by-action overview; owners in parentheses)
# A1. Immediate safeguards for deployment (0–1 month)
# - What: Prohibit automatic enforcement actions solely based on model output; require a human-in-the-loop for high-risk decisions; implement a “watchlist” to flag anomalous scores for review.
# - Expected impact: Moderate reduction in excessive reliance on predictions; limit potential harm in the near term.
# - Resources: Policy staff, field supervisors, IT to enforce controls.
# - Timeline: 0–4 weeks.
# - Risks: Slower response in emergencies; potential backlog; need clear guidelines for human decision-makers.
# - Confidence: High; uncertainties relate to operational enforcement.
#
# A2. Enforce data lineage and governance (0–2 months)
# - What: Inventory data sources, define data lineage, retention, and access controls; map which features derive from historical policing behavior vs. real-time context.
# - Expected impact: Improves ability to diagnose bias sources; reduces leakage of biased signals.
# - Resources: Data governance team; IT security; legal review.
# - Timeline: 0–8 weeks.
# - Risks: Resource-intensive; potential pushback from data producers.
# - Confidence: High.
#
# A3. Independent bias and fairness audit (0–3 months)
# - What: Commission an independent audit to assess fairness metrics (calibration by group, equalized odds, demographic parity), identify proxies for sensitive attributes, review data sampling and targets.
# - Expected impact: Establish baseline and concrete remediation targets; increase trust.
# - Resources: External audit firm, internal liaison.
# - Timeline: RFP in month 0–1; audit in months 1–3.
# - Risks: Auditor access to data; confidentiality considerations.
# - Confidence: High.
#
# A4. Debias training data and feature engineering (1–4 months)
# - What: Apply techniques to mitigate bias in training data (reweighting, resampling, causal modeling where feasible), remove or limit use of problematic proxies; consider using counterfactual fairness or causal risk models.
# - Expected impact: Reduce historical bias transmission; improve fairness metrics.
# - Resources: Data science team; compute; possible external expertise.
# - Timeline: 1–4 months.
# - Risks: Potential reduction in overall predictive performance; need to monitor for unintended effects.
# - Confidence: Medium-High.
#
# A5. Calibration and thresholding for equalized outcomes (2–5 months)
# - What: Re-calibrate scores by demographic group; adjust decision thresholds to achieve specified fairness objectives (e.g., equalized false positive rates or equal misclassification costs) while maintaining acceptable overall accuracy.
# - Expected impact: Direct reduction in disparate impacts; more uniform operation across groups.
# - Resources: Data scientists; policy/operations teams; governance oversight.
# - Timeline: 2–6 months.
# - Risks: Trade-off with accuracy; threshold drift over time needs ongoing monitoring.
# - Confidence: High.
#
# A6. Mitigate feedback loops with drift detection (2–6 months)
# - What: Implement monitoring for data drift and model drift; insert mechanisms to decouple current policing activity from model-generated data where feasible; refresh training data with more representative samples.
# - Expected impact: Stability against self-reinforcing biases; better long-run equity.
# - Resources: Data science + engineering; monitoring dashboards.
# - Timeline: 2–6 months.
# - Risks: Complexity of measuring drift in criminal data; requires ongoing maintenance.
# - Confidence: Medium-High.
#
# A7. Deployment governance and use-case refinement (3–7 months)
# - What: Define clear use cases for predictions (e.g., resource allocation planning vs. operational preemption); restrict areas or situations where scores drive decisions; require human decision-makers to consider context.
# - Expected impact: Reduces overbroad application of predictions; aligns with civil-rights safeguards.
# - Resources: Policy, legal, operations.
# - Timeline: 3–7 months.
# - Risks: Potential reduction in some predictive benefits; need careful communication with staff.
# - Confidence: High.
#
# A8. Community engagement and oversight mechanisms (4–8 months)
# - What: Establish Community Advisory Board (CAB), public dashboards with aggregate metrics, town halls, and a public data access policy for aggregated results; ensure accessible, multilingual communications.
# - Expected impact: Increased legitimacy, improved data quality through local feedback; stronger social license to operate.
# - Resources: Community relations; communications; data team.
# - Timeline: 4–8 months.
# - Risks: Potential politicization; must maintain privacy and security controls.
# - Confidence: High.
#
# A9. Vendor policy and procurement reforms (4–12 months)
# - What: Include fairness-by-design requirements in contracts; require model cards, audit rights, data provenance, versioning, and remediation plans; specify penalties for noncompliance; require third-party audits at defined intervals.
# - Expected impact: Structural incentive for fairness and transparency; clear accountability.
# - Resources: Legal, procurement, policy teams; potential legal reviews.
# - Timeline: 4–12 months.
# - Risks: Vendor resistance; negotiation complexity.
# - Confidence: High.
#
# A10. Public-facing transparency and educational materials (5–12 months)
# - What: Publish high-level model governance, fairness metrics, and remediation steps; avoid exposing sensitive details that could enable manipulation; provide resources for community members to understand policing changes.
# - Expected impact: Maintains trust and civic engagement; reduces speculation.
# - Resources: Communications; privacy/compliance.
# - Timeline: 5–12 months.
# - Risks: Privacy and security concerns; risk of misinterpretation.
# - Confidence: Medium-High.
#
# A11. Ongoing independent monitoring framework (6–12+ months)
# - What: Establish continuous independent evaluation, with quarterly public reports; annual full audit; data access controls for auditors; integrate independent feedback loops into governance.
# - Expected impact: Sustained accountability and long-term improvement.
# - Resources: Independent auditor commitments; governance body; IT for data access.
# - Timeline: Launch by month 6; ongoing thereafter.
# - Risks: Sustained funding and independence; confidentiality.
# - Confidence: High.
#
# A12. Contingency pause or re-engineering if targets not met (12 months)
# - What: If disparity metrics remain outside targets after full remediation window, pause deployment in affected geographies and pivot to non-predictive approaches or comprehensive reforms; re-evaluate system design.
# - Expected impact: Strong signal that civil-rights protections take priority; avoids perpetuating harm.
# - Resources: Governance and budget approvals.
# - Timeline: Triggered at 12 months if needed.
# - Risks: Public safety concerns; political ramifications.
# - Confidence: High; uncertainty about feasible alternatives.
#
# How these actions map to impact and resources
# - Impact on disparity: Most direct reductions from A3, A5, A6, A7, A9, A11; measurable improvements expected within 6–12 months if implemented rigorously.
# - Impact on public safety: Maintained or improved through careful calibration, human-in-the-loop processes, and governance; risk of short-term dip if thresholds restrict some predictive utility; mitigated by improved data quality and targeted interventions.
# - Human resources: 4–8 FTEs for governance, data science, and policy; external auditors for A3/A11; ongoing vendor management staff; community liaison roles.
# - Financial resources: Budget for audits, software governance tools, potential re-architecture, contract changes, and community engagement activities.
# - Timeline: Phased, with quick wins within 0–3 months (A1–A3) and longer-term governance and vendor changes by 6–12 months (A8–A11). Contingency action (A12) if targets not met.
#
# 3) Independent audit protocol to detect ongoing disparate harms
# Purpose
# - Detect whether the system continues to produce disparate harms and to attribute root causes.
#
# Data to collect (with privacy and legal guardrails)
# - Aggregated, de-identified incident-level data linked to model predictions, outcomes, and geographies (e.g., census tracts or neighborhoods) with time stamps.
# - Predicted risk scores and corresponding real-world outcomes (whether an incident occurred, arrests, or verified crimes).
# - Group-level identifiers allowed by law and policy (e.g., race/ethnicity proxies at aggregate level, or neighborhood-level demographic composition). Use synthetic or grouped data if individual attributes cannot be disclosed.
# - Deployment context data: policing posture in each area, officer density, time-of-day, resource allocation.
#
# Tests and analyses (in a protocol)
# - Fairness tests:
#   - Calibration by group: compare predicted risk to observed outcomes within each group; check calibration slope and intercept per group.
#   - Equalized odds: compare TPR and FPR across groups; ensure gaps are within predefined thresholds (e.g., <= 0.05 difference in TPR and FPR).
#   - Demographic parity (where legally permissible): compare positive prediction rates by group; target disparity <= 0.05 in absolute difference or within 0.8–1.25 ratio range.
# - Causal and quasi-experimental tests:
#   - Propensity score weighting to adjust for socio-economic confounders; examine residual association between group membership and predictions after adjustment.
#   - Difference-in-differences around policy changes to assess whether interventions affect disparities.
#   - Sensitivity analyses for unmeasured confounding in the observed disparities.
# - Robustness and leakage checks:
#   - Feature attribution and SHAP-like explanations to identify proxies for sensitive attributes; remove or constrain problematic features.
#   - Temporal drift analyses to detect shifts in data distribution and model behavior.
# - Validation and governance checks:
#   - Reproducibility: fixed data windows, versioned data, and model cards for each release.
#   - Audit trails: complete logs of data used, features, model versions, predictions, and human actions taken.
#
# Thresholds for action (indicators to trigger remediation)
# - If calibration by group deviates from 1.0 by more than ±0.1 for any group, trigger recalibration and potential feature removal.
# - If equalized odds gaps exceed ±0.05 in TPR or FPR for any group for two consecutive quarterly audits, trigger remediation (A5/A6) and governance review.
# - If demographic parity differences exceed ±0.05 across multiple geographies for two consecutive audits, pause or re-scope deployment in those geographies (A7/A12).
# - If persistent drift is detected without remediation after two cycles, escalate to independent governance body and consider vendor changes (A9/A11).
#
# Auditor independence and transparency
# - Auditing body must be legally and organizationally independent from the city’s policing apparatus and from the vendor.
# - Public summary reports released on a regular cadence; full, detailed reports available to the council and the independent oversight board, with redactions where necessary to protect privacy.
# - Access to data and model artifacts governed by data-sharing agreements, with strict confidentiality and security protocols.
# - Auditor selection: competitive tender, rotation of lead auditors every 3–5 years; annual performance review and public disclosure of qualifications.
# - Transparency: publish model cards, data schemas, and fairness metrics in a publicly accessible dashboard, with user-friendly explanations for non-technical stakeholders.
#
# 4) A principled framework for trading off predictive accuracy, public safety, and civil-rights protections
# Core objective
# - Maximize public safety while meeting explicit civil-rights protections and maintaining accountable governance.
#
# Operationalization steps
# - Define objective function with constraints:
#   - Primary objective: maximize net public safety benefit (e.g., reductions in crime rates, reductions in violent incidents) and minimize harms caused by false positives.
#   - Constraints: maintain fairness thresholds (calibration by group, equalized odds, and, where legally permissible, demographic parity) within specified bounds; require human oversight for high-risk predictions; preserve privacy and civil liberties.
# - Fairness criteria selection (practical guidance):
#   - Use multiple fairness notions to capture different harms; no single metric will satisfy all fairness criteria due to known impossibility results (Kleinberg et al. 2016/2017). Report trade-offs among metrics and justify choices.
#   - Calibrate the model by group so that each group’s observed risk aligns with predicted risk (calibration within groups).
#   - Choose a preferred fairness constraint (e.g., equalized odds or equalized calibration) based on policy priorities and legal requirements; consider multiple models or operating points to illustrate trade-offs.
# - Operational thresholds and accept/reject rules:
#   - If the model’s fairness metrics cannot be brought into alignment without unacceptable losses in predictive utility, constrain usage to non-discretionary, non-actionable predictions for certain contexts; emphasize human-centered decision processes.
#   - Maintain a policy of “no automated discretionary action without human review” for high-risk predictions, especially those that would trigger stops or detentions.
# - Monitoring and learning loop:
#   - Establish quarterly reviews of both accuracy and fairness metrics; adjust thresholds and training data with the independent audit’s recommendations.
#   - Introduce a governance veto on deploying changes that would meaningfully degrade civil-rights protections.
# - Time horizon and signaling:
#   - Short-term operationalization: prioritize constraints and human-in-the-loop processes; demonstrate improvements in fairness metrics within 6–12 months.
#   - Long-term sustainability: embed continuous fairness evaluation in standard practice (A3–A11) and ensure community oversight is ongoing.
#
# Operationalizing fairness and monitoring
# - Use model cards and data sheets for transparency (documentation of data sources, model inputs, performance metrics by group, and limitations).
# - Publish accessible dashboards showing aggregated metrics (crime outcomes, false positives, resource allocation) across geographies and over time.
# - Establish triggers for governance reviews if disparities widen or if performance degrades beyond agreed thresholds.
#
# Key uncertainties and how they could affect recommendations
# - If legal restrictions limit collection of sensitive attributes or group proxies, fairness verification may rely on proxy measures (uncertainties in their validity). Plan alternative proxies and document limitations.
# - If the city cannot attain acceptable fairness thresholds without sacrificing too much predictive accuracy, the framework suggests restricting deployment to non-predictive uses or reducing scope, with public communication and community involvement.
# - If historical crime rates in certain neighborhoods reflect under-reporting or other data issues, fairness tests may overstate disparities; the audit protocol includes causal analyses to address this.
# - Vendor capabilities vary; if a vendor cannot meet fairness-by-design requirements within budget, plan for competitive procurement and longer-term reengineering with phasing to avoid operational disruption.
# - Unintended consequences: tightening safeguards may reduce predictive utility in the short term, potentially affecting legitimate crime prevention efforts; this must be transparently communicated and mitigated with improved data quality and governance.
#
# 5) The top five factual questions to city officials or vendors (and how answers would shift actions)
# Question 1: What data sources feed the predictive model, and to what extent do they reflect policing practices or past enforcement priorities?
# - Plausible answer implications:
#   - If data are heavily biased by past enforcement, treat as a top-priority bias source (A3–A6) requiring data reweighting, removal of biased proxies, and increased emphasis on real-time contextual features; prioritize data governance and audit remediation (A2, A3, A5).
#   - If data reflect broader crime indicators with limited policing bias, fairness remediation may focus more on thresholds and governance rather than data removal (A5, A7).
# Question 2: Does the vendor provide a formal model card and a documented fairness assessment, including calibration by group and equalized odds analyses?
# - Plausible answer implications:
#   - If not, initiate binding contractual requirements for fairness testing, independent audits, and model-card disclosures (A9, A3, A11).
#   - If yes but with limited granularity, demand more rigorous, public-facing dashboards and independent audit validation (A11, A3).
# Question 3: What safeguards exist around human-in-the-loop decisions, and how are high-risk predictions handled in practice?
# - Plausible answer implications:
#   - If safeguards are weak, implement immediate A1 safeguards and strengthen deployment policy (A1, A7).
#   - If safeguards are strong, focus on governance improvements and more robust monitoring to ensure consistent human oversight (A7, A11).
# Question 4: What data-sharing and privacy protections apply to data used for audits and model evaluation, and who can access them?
# - Plausible answer implications:
#   - If access is too restricted, push for independent audits with legally defined data access windows and redacted data, per A3 and A11.
#   - If access is already appropriate, ensure ongoing transparency via public dashboards and annual audit reports (A8, A11).
# Question 5: What remedies exist if disparities persist after remediation (e.g., pause, re-engineering, or reallocation of resources)?
# - Plausible answer implications:
#   - If remedies exist and are actionable (A12), prepare for contingent actions; if remedies are weak or ambiguous, advocate for a governance framework with explicit triggers and public reporting (A12, A11, A8).
#
# 6) Confidence levels and key uncertainties for major recommendations
# - Immediate safeguards (A1): Confidence high; risk of emergency response delays is manageable with clear guidelines for urgent scenarios. Uncertainty: how best to define “high-risk” conditions for automatic human review.
# - Data lineage and governance (A2): Confidence high; essential for traceability. Uncertainty: comprehensiveness across all data sources; possible unidentified data flows.
# - Independent bias/fairness audit (A3): Confidence high; foundational for credibility. Uncertainty: scope of access and potential confidentiality constraints.
# - Debias training data (A4): Confidence medium-high; can reduce historical bias but may impact predictive performance. Uncertainty: which features are truly causal versus proxies; risk of over-correction.
# - Calibration and thresholding (A5): Confidence high; directly addresses fairness across groups. Uncertainty: optimal trade-offs between fairness and accuracy in different contexts.
# - Drift detection and feedback loop mitigation (A6): Confidence medium-high; feasible with modern monitoring, but effectiveness depends on data availability and timely model retraining.
# - Deployment governance (A7): Confidence high; operationally critical to ensure appropriate use. Uncertainty: balance between staffing and responsiveness; potential slowdowns in urgent responses.
# - Community engagement (A8): Confidence high; improves trust and legitimacy. Uncertainty: long-term engagement effects and possible politicization.
# - Vendor policy reform (A9): Confidence high; aligns incentives. Uncertainty: vendor capacity to comply; contract negotiation complexity.
# - Public transparency (A10): Confidence medium-high; enhances accountability but must protect privacy. Uncertainty: how much detail can be publicly shared without compromising security.
# - Ongoing independent monitoring (A11): Confidence high; essential for accountability. Uncertainty: funding sustainability; independence maintenance over time.
# - Contingency plan (A12): Confidence high; provides a clear path to protection if remediation stalls. Uncertainty: political and operational feasibility of pausing deployments.
#
# What the council should do now, and why
# - Immediately tighten governance and safeguards (A1–A3): Establish human oversight, halt unreviewed automated actions, and begin an independent bias/audit baseline. This reduces risk of ongoing harms while you work on longer-term remediation.
# - Commission independent audits (A3) and begin data lineage work (A2): These steps identify root causes and establish a credible road map for remediation; they are foundational for all subsequent actions.
# - Initiate bias correction and fairness calibration (A4–A5): Debias training data and recalibrate risk scores across groups to reduce disparities without sacrificing public safety, as much as possible.
# - Establish community engagement and oversight (A8) and strengthen vendor accountability (A9): Build legitimacy and ensure that the system reflects community values and legal obligations.
# - Implement ongoing monitoring and an independent monitoring framework (A11): Ensure sustained accountability and continuous improvement; publish transparent reports (A10) to maintain trust.
# - Prepare for a contingency pause or re-engineering if targets aren’t met (A12): Demonstrates that civil-rights protections are paramount and provides a clear exit pathway if remediation stalls.
#
# Key precedents, principles, and empirical grounding
# - Disparities in predictive policing documented in Lum & Isaac (2016), ProPublica COMPAS analysis (2016), and follow-up critiques; highlight that data and societal bias can manifest in algorithmic outputs.
# - Fairness impossibility results (Kleinberg, Mullainathan, Raghavan; Kleinberg et al., 2016, 2017) showing that equalizing all fairness metrics simultaneously is generally impossible when base rates differ; the framework here uses multiple metrics and explicit trade-offs rather than a single “perfect” metric.
# - Barocas & Selbst (2016) on bias in algorithmic decision-making and the necessity of governance, transparency, and human oversight.
# - NIST AI RMF and related governance literature emphasize risk management, transparency, accountability, and independent auditing as core pillars for responsible AI in public sector use.
#
# Confidence statements and uncertainties
# - The strongest action cluster (A1–A3, A7–A9) has high confidence because it directly reduces the likelihood of ongoing harm, creates governance mechanisms, and compels vendors to align with fairness and transparency obligations.
# - The data- and model-centric actions (A4–A6) depend on data quality and the ability to disentangle causality; they are likely to yield improvements but require careful implementation to avoid unintended performance losses.
# - Community engagement (A8) is essential for legitimacy; however, its effectiveness depends on sustained commitment, resource allocation, and the willingness of residents to participate meaningfully.
# - The long-term monitoring (A11) and transparency (A10) are essential but rely on sustained funding and political support.
# - The contingency option (A12) is prudent but may carry political and operational risk if invoked.
#
# Executive recommendation: what the council should do now
# - Approve an immediate, tightly scoped set of safeguards (A1) and commission an independent bias/fairness audit (A3) while initiating data governance work (A2). This provides immediate risk reduction and a credible baseline.
# - Simultaneously begin fairness calibration (A5) and establish a deployment governance framework (A7) to ensure any future use of predictions is context-aware and human-in-the-loop.
# - Launch a Community Advisory Board (A8) and contract a formal vendor reform path (A9) to ensure civil-rights protections and transparency.
# - Establish ongoing independent monitoring (A11) with quarterly public reports (A10) to maintain accountability and continuous improvement.
# - If, after 12 months, disparities persist beyond agreed thresholds, activate the contingency pause or re-engineering plan (A12) and reassess the system’s role in public safety.
#
# Final note
# - The city should recognize that fairness and safety are not binary choices but a spectrum of trade-offs. The recommended plan emphasizes governance, transparency, independent assessment, and community involvement as the pillars for restoring equity and public trust while preserving legitimate crime prevention goals. The actions are designed to be implementable within a 12-month frame, with a clear auditable path and measurable milestones.
#
# Appendix: Suggested metrics to track (examples)
# - Disparity metrics: disparate impact ratio (minority vs nonminority positive rate), equalized odds gap (TPR/FPR differences by group), calibration slope by group.
# - Predictive performance: AUC/ROC by group, Brier score overall and by group.
# - Process metrics: time from prediction to action, number of high-risk predictions reviewed by humans, number of interventions deployed per month.
# - Governance metrics: number of audit findings resolved, vendor compliance incidents, community meeting attendance and sentiment, data access requests fulfilled.
#
# If you would like, I can tailor the actions, timelines, and metrics to the city’s existing budgets, governance structures, and vendor contracts, and provide a one-page executive briefing for council members.
# Competitor: claude-sonnet-4-6
#
# # PREDICTIVE POLICING DISPARITY: COMPREHENSIVE COUNCIL REPORT
#
# ## Prepared for the City Council | Independent Consultant Assessment
#
# ---
#
# > **Executive Summary**
# >
# > This report presents findings and recommendations regarding demonstrated racial and geographic disparities in the city's AI-based predictive policing system. The evidence base for algorithmic bias in predictive policing is substantial and growing; disparity in this system is neither surprising nor inevitable, but it demands structured, urgent response. I recommend the council immediately suspend autonomous decision-making authority vested in the system, establish independent oversight, and pursue a 12-month remediation plan detailed herein. The cost of inaction—continued civil rights harm, litigation exposure, community trust erosion, and likely federal scrutiny—substantially exceeds the cost of remediation. My confidence in the core diagnosis is high; my confidence in specific technical fixes is moderate, contingent on answers to factual questions identified in Section VI.
#
# ---
#
# ## TABLE OF CONTENTS
#
# 1. Causes of Disparity: Technical and Non-Technical
# 2. 12-Month Prioritized Remediation Plan
# 3. Action-by-Action Impact and Resource Analysis
# 4. Independent Audit Protocol
# 5. Principled Framework for Balancing Accuracy, Safety, and Civil Rights
# 6. Key Factual Questions for City Officials and Vendors
# 7. Immediate Recommendations and Rationale
# 8. References and Precedents
#
# ---
#
# ## SECTION I: CAUSES OF DISPARITY — TECHNICAL AND NON-TECHNICAL
#
# Understanding *why* the system produces disparate outcomes is essential before prescribing solutions. The causes are almost certainly multiple, interactive, and mutually reinforcing. I distinguish seven categories below.
#
# ### 1.1 Technical Causes
#
# #### 1.1.1 Biased Training Data (Historical Crime Records)
#
# **What it is:** The model was trained on historical arrest, stop, citation, or crime report data that itself reflects prior discriminatory policing patterns.
#
# **Why it matters:** If police historically concentrated enforcement in minority neighborhoods—whether due to explicit policy, implicit bias, or political decisions—arrest and citation records will overrepresent those neighborhoods even if underlying criminal behavior is distributed differently across the city. Training a model on this data does not reveal ground truth about crime; it reveals ground truth about *prior police behavior*. The model then predicts where police made arrests, not necessarily where crime occurs. This is sometimes called the "dirty data" problem, documented systematically by researchers including Rashida Richardson and colleagues (2019) in their examination of "dirty data" cities.
#
# **Confidence this is present:** High. Nearly every predictive policing deployment using historical crime data is susceptible to this problem. The observed disparity is consistent with this mechanism.
#
# #### 1.1.2 Label Bias
#
# **What it is:** The outcome variable (the "label") the model is trained to predict is itself a biased proxy for the true phenomenon of interest.
#
# **Why it matters:** Models typically predict "reported crime," "arrests," or "calls for service" rather than actual crime incidence. These labels are differentially generated: a robbery in a wealthy neighborhood is more likely to be called in, investigated, and result in an arrest than an equivalent act in a neighborhood where residents distrust police or where police resources are thinner. If the label is "arrests" rather than "crimes," the model learns to predict enforcement intensity, not safety risk. This distinction—between *crime* and *detected crime*—is foundational to understanding algorithmic bias in criminal justice (Lum and Isaac, 2016, demonstrated this explicitly using drug use data in Oakland).
#
# **Confidence this is present:** High.
#
# #### 1.1.3 Feedback Loops (Performative Prediction)
#
# **What it is:** The model's predictions influence where police patrol, which generates more arrests in predicted locations, which are fed back as training data, which reinforces the original predictions in a self-amplifying cycle.
#
# **Why it matters:** This is arguably the most dangerous technical mechanism because it compounds over time. Even a model with modest initial bias can produce extreme disparities after several feedback cycles. Research by Ensign and colleagues (2018) formally modeled this dynamic and demonstrated that feedback loops in predictive policing can drive patrol allocation toward a fixed point that bears little relationship to underlying crime distribution. The system becomes, in effect, a self-fulfilling prophecy.
#
# **Confidence this is present:** High if the model's outputs are used to direct patrol resources and the resulting enforcement data is fed back into model retraining. This is
# Competitor: deepseek-chat
#
# **To:** City Council
# **From:** Independent Consultant
# **Date:** October 26, 2023
# **Subject:** Report on Predictive Policing System Disparities & Remediation Plan
#
# ---
#
# ### **Executive Summary**
#
# Our audit confirms the AI-based predictive policing system disproportionately targets minority neighborhoods. This disparity arises from a combination of **technical flaws** (biased training data, label bias, feedback loops) and **non-technical factors** (historical policing patterns, socio-economic confounders, deployment decisions). Left unaddressed, the system risks exacerbating inequality, eroding community trust, and violating civil rights. This report provides a causal analysis, a 12-month remediation plan, an independent audit protocol, a principled trade-off framework, and key questions for officials. **I recommend the council immediately suspend the system’s use for patrol decisions and initiate the proposed remediation plan.**
#
# ---
#
# ### **1. Causes of Disparity**
#
# #### **Technical Causes**
# - **Biased Training Data:** Historical crime data reflect over-policing of minority neighborhoods (e.g., higher arrest rates for low-level offenses), embedding past bias into predictions (*“garbage in, garbage out”*).
# - **Label Bias:** Using arrests or reported crimes as “crime” labels conflates crime prevalence with policing intensity. This is a well-documented source of bias (e.g., Lum & Isaac, 2016).
# - **Feedback Loops:** Predicted hotspots lead to more patrols, which generate more recorded incidents, reinforcing future predictions (a “self-fulfilling prophecy”).
# - **Deployment Decisions:** Thresholds for “high risk” may be set without fairness considerations, amplifying disparities.
#
# #### **Non-Technical Causes**
# - **Policing Practices:** Resource allocation, officer discretion, and community reporting rates differ across neighborhoods.
# - **Socio-Economic Confounders:** Poverty, density, and unemployment correlate with both minority status and some crime types—the system may proxy race via these variables.
# - **Vendor Contract & Oversight:** Lack of transparency in proprietary algorithms, absence of fairness constraints in procurement.
#
# ---
#
# ### **2. 12-Month Remediation Plan**
#
# | Priority | Action | Timeline | Resources Needed | Expected Impact on Disparity/Public Safety | Unintended Consequences/Risks |
# |----------|--------|----------|------------------|--------------------------------------------|-------------------------------|
# | **1. Immediate Safeguards** | Suspend system for patrol allocation; retain for internal analysis only. | Week 1 | Legal review, IT patch. | Halts amplification of bias; short-term uncertainty in patrol planning. | Officer pushback; potential temporary rise in response times. |
# | **2. Data & Model Audit** | Commission independent audit of training data, labels, and model outputs (see Section 4). | Months 1–3 | $80K–$120K for auditors; data engineer (city staff). | Identifies specific bias sources; informs model redesign. | Vendor resistance; may reveal deeper systemic biases. |
# | **3. Community Engagement** | Form oversight board with community reps, public defenders, civil rights advocates. | Months 1–12 (ongoing) | 0.5 FTE coordinator; stipends for community members. | Builds trust, ensures accountability, informs fairness criteria. | Board may lack technical expertise; potential for divisiveness. |
# | **4. Model & Process Redesign** | Redesign system with fairness constraints (e.g., demographic parity, equalized FPR), use alternative data (e.g., 911 calls only), and implement “fairness through awareness” (Dwork et al., 2012). | Months 4–9 | Data scientists (2 FTE), vendor renegotiation ($150K–$300K). | Reduces disparity; may slightly reduce accuracy for majority groups. | Trade-offs between fairness/accuracy; requires careful validation. |
# | **5. Policy & Contract Changes** | Update procurement to require fairness reports, transparency, and city ownership of data/models. | Months 6–12 | Legal, procurement staff. | Prevents future vendor lock-in and black-box systems. | Higher upfront costs; vendors may resist. |
# | **6. Pilot & Monitor** | Pilot revised system in limited districts with pre-specified fairness thresholds. | Months 10–12 | Patrol coordination, monitoring team. | Allows real-world testing of fairness/accuracy trade-offs. | Possible community skepticism even with improvements. |
#
# ---
#
# ### **3. Action Details & Confidence**
#
# - **Immediate Suspension:** *High confidence* based on precedent (e.g., NYPD’s early predictive policing issues). Key uncertainty: contractual penalties with vendor.
# - **Independent Audit:** *High confidence*; necessary for diagnosing specific bias. Uncertainty: data accessibility.
# - **Community Oversight Board:** *Medium confidence*; critical for legitimacy, but effectiveness depends on representation and authority.
# - **Model Redesign:** *Medium confidence*; technical solutions exist but require careful implementation to avoid other harms.
#
# ---
#
# ### **4. Independent Audit Protocol**
#
# **Objective:** Detect disparate harms in predictions vs. outcomes.
#
# **Data Required:**
# - Model predictions (by location/demographic).
# - Ground-truth crime data (victimization surveys, 911 calls).
# - Patrol records (stops, arrests, use of force).
# - Demographic data (census, neighborhood composition).
#
# **Statistical Tests:**
# - **Disparate Impact Ratio:** Compare prediction rates across racial groups.
# - **Error Rate Analysis:** False positive/negative rates by group.
# - **Causal Tests:** Instrumental variables or difference-in-differences to assess feedback loops.
#
# **Acceptable Thresholds:**
# - 80% rule (disparate impact ratio ≥0.8) for initial screening.
# - Statistical significance (p<0.05) for error rate differences.
# - **Action Trigger:** Any violation requires mitigation before redeployment.
#
# **Auditor Independence:**
# - Third-party selection by council + community board.
# - Full transparency: public report, code, and data (where privacy-safe).
#
# ---
#
# ### **5. Principled Trade-Off Framework**
#
# Council should adopt a **“Fairness, Accountability, and Transparency”** framework:
#
# 1. **Operationalize Fairness:** Choose a fairness metric (e.g., equalized false positive rates) based on community input and legal advice. Different definitions (e.g., demographic parity vs. equalized odds) have different trade-offs (Kleinberg et al., 2017).
# 2. **Accept Accuracy Reductions:** If needed, prioritize reducing disparities over marginal gains in overall prediction accuracy. Precedent: Berkeley’s dropped predictive policing due to equity concerns.
# 3. **Monitor Outcomes:** Track both crime rates and community trust metrics (surveys, complaint rates). Use control districts without the system for comparison.
# 4. **Decision Rule:** System redeployment only if it meets pre-agreed fairness thresholds and does not increase disproportionate stops/arrests.
#
# ---
#
# ### **6. Top Five Factual Questions for City/Vendor**
#
# 1. **“What specific crime data and labels were used to train the model?”**
#    - *If arrest data only:* Urgent need to switch to victimization data.
#    - *If mixed sources:* Audit label definitions for bias.
#
# 2. **“How are model predictions translated into patrol decisions (thresholds, human override)?”**
#    - *If fully automated:* Immediate need for human-in-the-loop.
#    - *If discretionary:* Assess officer training and guidelines.
#
# 3. **“What fairness tests were conducted before deployment, and what disparities were found?”**
#    - *If none:* Indicates vendor negligence; consider contract termination.
#    - *If tests showed disparities but were ignored:* Need policy changes to mandate fairness.
#
# 4. **“What is the contractual exit cost and data ownership status?”**
#    - *If high exit cost:* Phase out while developing in-house capacity.
#    - *If city owns data/model:* More flexibility for redesign.
#
# 5. **“What is the historical disparity in police stops/arrests by neighborhood, independent of the AI system?”**
#    - *If high:* System may be amplifying existing bias; need broader policing reform.
#    - *If low:* Suggests technical flaws dominate.
#
# ---
#
# ### **Recommendation**
#
# **The council should immediately suspend the system’s operational use, commission an independent audit, and establish a community oversight board.** These steps halt harm, diagnose root causes, and ensure community voice in remediation. The proposed 12-month plan balances urgency with feasibility, addressing both technical and systemic factors. Continuing without intervention risks legal liability, deepened distrust, and perpetuation of inequity.
#
# ---
# **Confidence:** High for immediate suspension and audit; medium for long-term redesign due to vendor and data uncertainties.
# **Citations:** Lum & Isaac (2016), Dwork et al. (2012), Kleinberg et al. (2017), Berk et al. (2021) on fairness trade-offs.
# Competitor: llama3.2
#
# **Report: Remediation Plan for AI‑Based Predictive Policing System**
#
# **I. Introduction**
#
# The city's AI-based predictive policing system has been shown to disproportionately target minority neighborhoods, raising concerns about systemic bias and potential harm to communities of color. This report aims to provide a comprehensive analysis of the plausible causes of the disparity and proposed a prioritized 12-month remediation plan to address these issues.
#
# **II. Causes of Disparity**
#
# Technical causes:
#
# 1. **Biased training data**: Inadequate or skewed training datasets can perpetuate existing biases.
# 2. **Label bias**: Labelling patterns in historical crime data may reflect discrimination against minority groups.
# 3. **Feedback loops**: The system's self-reinforcing nature can amplify biased assumptions and predictions.
#
# Non-technical causes:
#
# 1. **Policing practices**: Aggressive policing tactics, racial profiling, and over-policing of minority neighborhoods contribute to the disparity.
# 2. **Socio-economic confounders**: Systematic differences in poverty rates, education levels, and employment opportunities across neighborhoods can skew crime data.
# 3. **Deployment decisions**: The system's algorithms are deployed without adequate consideration for community context, exacerbating biases.
#
# **III. Remediation Plan**
#
# A. Immediate Safeguards (Months 1-3)
#
# 1. **Data audit**: Conduct a thorough review of training data to identify patterns and biases (Estimated impact on disparity: −20%).
# 2. **System auditing**: Perform regular checks for updates, anomalies, and bias-related issues.
# 3. **Community outreach**: Engage in community forums to raise awareness and establish a dialogue on AI-based policing.
#
# B. Data and Model Updates (Months 4-6)
#
# 1. **Model adjustments**: Implement data-driven updates to reduce bias in algorithms ($100,000 - $300,000).
# 2. **Training dataset refresh**: Regularly update training datasets to reflect changing community demographics.
# 3. **External validation**: Engage with independent experts for model testing and validation.
#
# C. Deployment and Decision-Making Changes (Months 7-9)
#
# 1. **Algorithmic adjustments**: Implement algorithms that prioritize contextual understanding over simplistic rules ($150,000 - $400,000).
# 2. **Deployment guidelines**: Develop and deploy guidelines to address potential biases in deployment decisions.
# 3. **Training for officers**: Provide training on AI-based policing tools and their limitations.
#
# D. Community Engagement and Oversight (Months 10-12)
#
# 1. **Community advisory board**: Establish an independent community board to monitor the system's performance.
# 2. **Regular audits**: Perform quarterly audits to assess disparities and adjust mitigation strategies as needed.
# 3. **Policy oversight**: Conduct regular review of policy changes aligning with community feedback and expert input.
#
# E. Policy and Contractual Changes (Months 12-18)
#
# 1. **Racial bias policy**: Develop a city-wide policy on AI-based policing, emphasizing fairness and equity ($200,000 - $500,000).
# 2. **Vendor contract reviews**: Conduct regular reviews of contracts with vendors to ensure compliance with bias mitigation measures.
# 3. **Transparency reporting**: Establish clear reporting guidelines for transparency regarding the system's performance.
#
# **IV. Independent Audit Protocol**
#
# A. Data Collection:
#
# 1. Disaggregate crime data by neighborhood type and demographic groupings.
# 2. Analyze deployment patterns, response rates, and outcomes (e.g., arrests, convictions).
#
# B. Statistical and Causal Tests:
#
# 1. Apply regression analysis to assess disparities in historical crime data.
# 2. Employ causality tests to determine whether algorithmic predictions lead to distinct changes in policing behaviors.
#
# C. Acceptable Thresholds for Action:
#
# 1. Establish benchmarks for disparity reduction targets (e.g., 15%); adjust these as necessary.
# 2. Engage with local experts and civil society organizations to set thresholds for bias recognition.
#
# D. Auditor Independence and Transparency
#
# 1. Ensure the independent auditor has no direct affiliation with vendors or internal stakeholders.
# 2. Implement a structured process for sharing findings, recommendations, and system evaluation data with relevant city departments, community boards, and external stakeholders.
#
# **V. Principles for Tradeoff Between Predictive Accuracy, Public Safety, and Civil-Rights Protections**
#
# To balance predictive accuracy, public safety, and civil-rights protections:
#
# 1. **Data-driven decision-making**: Leverage objective data to underpin policing decisions.
# 2. **Algorithmic explainability**: Ensure algorithms provide robust explanations for recommendations.
# 3. **Community-centric approaches**: Prioritize contextual understanding and feedback from affected communities.
#
# These core principles inform adjustments in model deployment, decision-making processes, and ongoing community engagement throughout the project timeline.
#
# **VI. Top Five Questions to Ask City Officials or Vendors**
#
# 1. What data sources were used to develop the predictive policing system?
# 2. How has the system been validated against diverse training datasets, including samples representing minority populations?
#
# **VII. Conclusion and Confidence Level**
#
# This report emphasizes a 12-month remediation plan focused on immediate safeguards, ongoing audits, strategic software updates, deployment changes, and community oversight. To ensure our recommendations are effective, I set high confidence levels across most measures. However, uncertainties related to data availability, model explanations, vendor compliance with regulations, and societal perceptions of AI must be addressed.
#
# The best path forward is that the council engages in this collaborative framework with local stakeholders to identify specific questions and address emerging concerns.
#
# We recommend:
#
# 1. The city implement these measures to address disparity.
# 2. Regular community engagement ensures buy-in for systemic improvements.
#
# These priorities will allow the system to improve its performance and prioritize protection over prediction

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Council-ready report: Addressing disparities in an AI-based predictive policing system
#
# Date: [Insert date]
#
# Executive summary
# - Problem: An AI-driven predictive policing system is disproportionately flagging minority neighborhoods, raising civil-rights concerns and eroding public trust.
# - Core finding: Disparities arise from a mix of technical causes (biased historical data, label bias, feedback loops, feature leakage, data quality gaps) and non-technical causes (policing practices, deployment choices, socio-economic confounders, governance and contractor practices).
# - Plan: A 12-month remediation program combining immediate safeguards, data/model audits, deployment/process changes, community oversight, and binding vendor policy changes; plus an independent audit protocol and a principled framework to balance accuracy, public safety, and civil rights.
# - Outcome sought: Reduced bias in predictions while preserving or improving public safety, with transparent, auditable processes and robust community oversight.
#
# 1) Plausible causes of disparity: technical vs. non-technical
# A. Technical causes
# - Biased training data
#   - Historical policing records reflect prior enforcement biases (e.g., over-policing in minority neighborhoods), creating biased predictive signals.
# - Label bias
#   - The target variable (crime labels, arrests, gun detections) may reflect enforcement practices and not true underlying risk, injecting label bias.
# - Feedback loops
#   - Predicted risk drives policing activity in certain areas, generating more incident data there and reinforcing the model’s belief that those areas are high risk (self-fulfilling loop).
# - Data quality and representation gaps
#   - Missing data, under-reporting in some communities, or insufficient coverage of certain geographies skew model training.
# - Feature biases and leakage
#   - Proximity to police facilities, prior stop frequencies, or census-geography proxies can act as proxies for sensitive attributes; models may learn spurious correlations with protected groups.
# - Model design choices
#   - Complexity or training procedures that optimize overall accuracy at the expense of fairness; failure to calibrate scores across groups.
# - Temporal drift and nonstationarity
#   - Crime patterns shift; models trained on older data misrepresent current risk, potentially differentially affecting groups.
# B. Non-technical causes
# - Policing practices and policy
#   - Law enforcement priorities, discretionary stops, or geofenced deployment that concentrate effort in particular neighborhoods.
# - Deployment decisions and governance
#   - Where and how predictions influence action (e.g., early-warning flags vs. reactive discretion) shapes how disparities translate into outcomes.
# - Socio-economic confounders
#   - Structural inequalities (poverty, housing, education, limited legitimate opportunities) correlate with crime metrics and neighborhood demographics, confounding causal interpretation.
# - Vendor and procurement factors
#   - Contracts that emphasize predictive accuracy without fairness requirements; opaque model provenance; lack of independent audits.
# - Community trust and data sharing
#   - Under-resourced communities may have lower engagement or reporting rates, affecting data representativeness.
#
# Notes on causality and interpretation
# - Many causes are interdependent. For example, biased training data + feedback loops + policing deployment choices can magnify disparities even when the underlying model is technically well-behaved.
# - Distinguishing between short-term remediation (e.g., threshold re-calibration) and long-term systemic reform (e.g., governance reforms, data collection improvements) is essential.
#
# 2) A prioritized, feasible 12-month remediation plan
# Guiding principles
# - Immediate safeguards first: ensure human review, prohibit automatic discretionary actions based solely on risk scores, and place a cap on high-stakes decisions driven by the model.
# - Data and model transparency: audits, audits, audits—internal and independent.
# - Community oversight: establish protections and channels for affected communities; publish aggregate metrics and progress.
# - Vendor accountability: contractually bind fairness, transparency, and audit rights.
#
# 12-month plan (action-by-action overview; owners in parentheses)
# A1. Immediate safeguards for deployment (0–1 month)
# - What: Prohibit automatic enforcement actions solely based on model output; require a human-in-the-loop for high-risk decisions; implement a “watchlist” to flag anomalous scores for review.
# - Expected impact: Moderate reduction in excessive reliance on predictions; limit potential harm in the near term.
# - Resources: Policy staff, field supervisors, IT to enforce controls.
# - Timeline: 0–4 weeks.
# - Risks: Slower response in emergencies; potential backlog; need clear guidelines for human decision-makers.
# - Confidence: High; uncertainties relate to operational enforcement.
#
# A2. Enforce data lineage and governance (0–2 months)
# - What: Inventory data sources, define data lineage, retention, and access controls; map which features derive from historical policing behavior vs. real-time context.
# - Expected impact: Improves ability to diagnose bias sources; reduces leakage of biased signals.
# - Resources: Data governance team; IT security; legal review.
# - Timeline: 0–8 weeks.
# - Risks: Resource-intensive; potential pushback from data producers.
# - Confidence: High.
#
# A3. Independent bias and fairness audit (0–3 months)
# - What: Commission an independent audit to assess fairness metrics (calibration by group, equalized odds, demographic parity), identify proxies for sensitive attributes, review data sampling and targets.
# - Expected impact: Establish baseline and concrete remediation targets; increase trust.
# - Resources: External audit firm, internal liaison.
# - Timeline: RFP in month 0–1; audit in months 1–3.
# - Risks: Auditor access to data; confidentiality considerations.
# - Confidence: High.
#
# A4. Debias training data and feature engineering (1–4 months)
# - What: Apply techniques to mitigate bias in training data (reweighting, resampling, causal modeling where feasible), remove or limit use of problematic proxies; consider using counterfactual fairness or causal risk models.
# - Expected impact: Reduce historical bias transmission; improve fairness metrics.
# - Resources: Data science team; compute; possible external expertise.
# - Timeline: 1–4 months.
# - Risks: Potential reduction in overall predictive performance; need to monitor for unintended effects.
# - Confidence: Medium-High.
#
# A5. Calibration and thresholding for equalized outcomes (2–5 months)
# - What: Re-calibrate scores by demographic group; adjust decision thresholds to achieve specified fairness objectives (e.g., equalized false positive rates or equal misclassification costs) while maintaining acceptable overall accuracy.
# - Expected impact: Direct reduction in disparate impacts; more uniform operation across groups.
# - Resources: Data scientists; policy/operations teams; governance oversight.
# - Timeline: 2–6 months.
# - Risks: Trade-off with accuracy; threshold drift over time needs ongoing monitoring.
# - Confidence: High.
#
# A6. Mitigate feedback loops with drift detection (2–6 months)
# - What: Implement monitoring for data drift and model drift; insert mechanisms to decouple current policing activity from model-generated data where feasible; refresh training data with more representative samples.
# - Expected impact: Stability against self-reinforcing biases; better long-run equity.
# - Resources: Data science + engineering; monitoring dashboards.
# - Timeline: 2–6 months.
# - Risks: Complexity of measuring drift in criminal data; requires ongoing maintenance.
# - Confidence: Medium-High.
#
# A7. Deployment governance and use-case refinement (3–7 months)
# - What: Define clear use cases for predictions (e.g., resource allocation planning vs. operational preemption); restrict areas or situations where scores drive decisions; require human decision-makers to consider context.
# - Expected impact: Reduces overbroad application of predictions; aligns with civil-rights safeguards.
# - Resources: Policy, legal, operations.
# - Timeline: 3–7 months.
# - Risks: Potential reduction in some predictive benefits; need careful communication with staff.
# - Confidence: High.
#
# A8. Community engagement and oversight mechanisms (4–8 months)
# - What: Establish Community Advisory Board (CAB), public dashboards with aggregate metrics, town halls, and a public data access policy for aggregated results; ensure accessible, multilingual communications.
# - Expected impact: Increased legitimacy, improved data quality through local feedback; stronger social license to operate.
# - Resources: Community relations; communications; data team.
# - Timeline: 4–8 months.
# - Risks: Potential politicization; must maintain privacy and security controls.
# - Confidence: High.
#
# A9. Vendor policy and procurement reforms (4–12 months)
# - What: Include fairness-by-design requirements in contracts; require model cards, audit rights, data provenance, versioning, and remediation plans; specify penalties for noncompliance; require third-party audits at defined intervals.
# - Expected impact: Structural incentive for fairness and transparency; clear accountability.
# - Resources: Legal, procurement, policy teams; potential legal reviews.
# - Timeline: 4–12 months.
# - Risks: Vendor resistance; negotiation complexity.
# - Confidence: High.
#
# A10. Public-facing transparency and educational materials (5–12 months)
# - What: Publish high-level model governance, fairness metrics, and remediation steps; avoid exposing sensitive details that could enable manipulation; provide resources for community members to understand policing changes.
# - Expected impact: Maintains trust and civic engagement; reduces speculation.
# - Resources: Communications; privacy/compliance.
# - Timeline: 5–12 months.
# - Risks: Privacy and security concerns; risk of misinterpretation.
# - Confidence: Medium-High.
#
# A11. Ongoing independent monitoring framework (6–12+ months)
# - What: Establish continuous independent evaluation, with quarterly public reports; annual full audit; data access controls for auditors; integrate independent feedback loops into governance.
# - Expected impact: Sustained accountability and long-term improvement.
# - Resources: Independent auditor commitments; governance body; IT for data access.
# - Timeline: Launch by month 6; ongoing thereafter.
# - Risks: Sustained funding and independence; confidentiality.
# - Confidence: High.
#
# A12. Contingency pause or re-engineering if targets not met (12 months)
# - What: If disparity metrics remain outside targets after full remediation window, pause deployment in affected geographies and pivot to non-predictive approaches or comprehensive reforms; re-evaluate system design.
# - Expected impact: Strong signal that civil-rights protections take priority; avoids perpetuating harm.
# - Resources: Governance and budget approvals.
# - Timeline: Triggered at 12 months if needed.
# - Risks: Public safety concerns; political ramifications.
# - Confidence: High; uncertainty about feasible alternatives.
#
# How these actions map to impact and resources
# - Impact on disparity: Most direct reductions from A3, A5, A6, A7, A9, A11; measurable improvements expected within 6–12 months if implemented rigorously.
# - Impact on public safety: Maintained or improved through careful calibration, human-in-the-loop processes, and governance; risk of short-term dip if thresholds restrict some predictive utility; mitigated by improved data quality and targeted interventions.
# - Human resources: 4–8 FTEs for governance, data science, and policy; external auditors for A3/A11; ongoing vendor management staff; community liaison roles.
# - Financial resources: Budget for audits, software governance tools, potential re-architecture, contract changes, and community engagement activities.
# - Timeline: Phased, with quick wins within 0–3 months (A1–A3) and longer-term governance and vendor changes by 6–12 months (A8–A11). Contingency action (A12) if targets not met.
#
# 3) Independent audit protocol to detect ongoing disparate harms
# Purpose
# - Detect whether the system continues to produce disparate harms and to attribute root causes.
#
# Data to collect (with privacy and legal guardrails)
# - Aggregated, de-identified incident-level data linked to model predictions, outcomes, and geographies (e.g., census tracts or neighborhoods) with time stamps.
# - Predicted risk scores and corresponding real-world outcomes (whether an incident occurred, arrests, or verified crimes).
# - Group-level identifiers allowed by law and policy (e.g., race/ethnicity proxies at aggregate level, or neighborhood-level demographic composition). Use synthetic or grouped data if individual attributes cannot be disclosed.
# - Deployment context data: policing posture in each area, officer density, time-of-day, resource allocation.
#
# Tests and analyses (in a protocol)
# - Fairness tests:
#   - Calibration by group: compare predicted risk to observed outcomes within each group; check calibration slope and intercept per group.
#   - Equalized odds: compare TPR and FPR across groups; ensure gaps are within predefined thresholds (e.g., <= 0.05 difference in TPR and FPR).
#   - Demographic parity (where legally permissible): compare positive prediction rates by group; target disparity <= 0.05 in absolute difference or within 0.8–1.25 ratio range.
# - Causal and quasi-experimental tests:
#   - Propensity score weighting to adjust for socio-economic confounders; examine residual association between group membership and predictions after adjustment.
#   - Difference-in-differences around policy changes to assess whether interventions affect disparities.
#   - Sensitivity analyses for unmeasured confounding in the observed disparities.
# - Robustness and leakage checks:
#   - Feature attribution and SHAP-like explanations to identify proxies for sensitive attributes; remove or constrain problematic features.
#   - Temporal drift analyses to detect shifts in data distribution and model behavior.
# - Validation and governance checks:
#   - Reproducibility: fixed data windows, versioned data, and model cards for each release.
#   - Audit trails: complete logs of data used, features, model versions, predictions, and human actions taken.
#
# Thresholds for action (indicators to trigger remediation)
# - If calibration by group deviates from 1.0 by more than ±0.1 for any group, trigger recalibration and potential feature removal.
# - If equalized odds gaps exceed ±0.05 in TPR or FPR for any group for two consecutive quarterly audits, trigger remediation (A5/A6) and governance review.
# - If demographic parity differences exceed ±0.05 across multiple geographies for two consecutive audits, pause or re-scope deployment in those geographies (A7/A12).
# - If persistent drift is detected without remediation after two cycles, escalate to independent governance body and consider vendor changes (A9/A11).
#
# Auditor independence and transparency
# - Auditing body must be legally and organizationally independent from the city’s policing apparatus and from the vendor.
# - Public summary reports released on a regular cadence; full, detailed reports available to the council and the independent oversight board, with redactions where necessary to protect privacy.
# - Access to data and model artifacts governed by data-sharing agreements, with strict confidentiality and security protocols.
# - Auditor selection: competitive tender, rotation of lead auditors every 3–5 years; annual performance review and public disclosure of qualifications.
# - Transparency: publish model cards, data schemas, and fairness metrics in a publicly accessible dashboard, with user-friendly explanations for non-technical stakeholders.
#
# 4) A principled framework for trading off predictive accuracy, public safety, and civil-rights protections
# Core objective
# - Maximize public safety while meeting explicit civil-rights protections and maintaining accountable governance.
#
# Operationalization steps
# - Define objective function with constraints:
#   - Primary objective: maximize net public safety benefit (e.g., reductions in crime rates, reductions in violent incidents) and minimize harms caused by false positives.
#   - Constraints: maintain fairness thresholds (calibration by group, equalized odds, and, where legally permissible, demographic parity) within specified bounds; require human oversight for high-risk predictions; preserve privacy and civil liberties.
# - Fairness criteria selection (practical guidance):
#   - Use multiple fairness notions to capture different harms; no single metric will satisfy all fairness criteria due to known impossibility results (Kleinberg et al. 2016/2017). Report trade-offs among metrics and justify choices.
#   - Calibrate the model by group so that each group’s observed risk aligns with predicted risk (calibration within groups).
#   - Choose a preferred fairness constraint (e.g., equalized odds or equalized calibration) based on policy priorities and legal requirements; consider multiple models or operating points to illustrate trade-offs.
# - Operational thresholds and accept/reject rules:
#   - If the model’s fairness metrics cannot be brought into alignment without unacceptable losses in predictive utility, constrain usage to non-discretionary, non-actionable predictions for certain contexts; emphasize human-centered decision processes.
#   - Maintain a policy of “no automated discretionary action without human review” for high-risk predictions, especially those that would trigger stops or detentions.
# - Monitoring and learning loop:
#   - Establish quarterly reviews of both accuracy and fairness metrics; adjust thresholds and training data with the independent audit’s recommendations.
#   - Introduce a governance veto on deploying changes that would meaningfully degrade civil-rights protections.
# - Time horizon and signaling:
#   - Short-term operationalization: prioritize constraints and human-in-the-loop processes; demonstrate improvements in fairness metrics within 6–12 months.
#   - Long-term sustainability: embed continuous fairness evaluation in standard practice (A3–A11) and ensure community oversight is ongoing.
#
# Operationalizing fairness and monitoring
# - Use model cards and data sheets for transparency (documentation of data sources, model inputs, performance metrics by group, and limitations).
# - Publish accessible dashboards showing aggregated metrics (crime outcomes, false positives, resource allocation) across geographies and over time.
# - Establish triggers for governance reviews if disparities widen or if performance degrades beyond agreed thresholds.
#
# Key uncertainties and how they could affect recommendations
# - If legal restrictions limit collection of sensitive attributes or group proxies, fairness verification may rely on proxy measures (uncertainties in their validity). Plan alternative proxies and document limitations.
# - If the city cannot attain acceptable fairness thresholds without sacrificing too much predictive accuracy, the framework suggests restricting deployment to non-predictive uses or reducing scope, with public communication and community involvement.
# - If historical crime rates in certain neighborhoods reflect under-reporting or other data issues, fairness tests may overstate disparities; the audit protocol includes causal analyses to address this.
# - Vendor capabilities vary; if a vendor cannot meet fairness-by-design requirements within budget, plan for competitive procurement and longer-term reengineering with phasing to avoid operational disruption.
# - Unintended consequences: tightening safeguards may reduce predictive utility in the short term, potentially affecting legitimate crime prevention efforts; this must be transparently communicated and mitigated with improved data quality and governance.
#
# 5) The top five factual questions to city officials or vendors (and how answers would shift actions)
# Question 1: What data sources feed the predictive model, and to what extent do they reflect policing practices or past enforcement priorities?
# - Plausible answer implications:
#   - If data are heavily biased by past enforcement, treat as a top-priority bias source (A3–A6) requiring data reweighting, removal of biased proxies, and increased emphasis on real-time contextual features; prioritize data governance and audit remediation (A2, A3, A5).
#   - If data reflect broader crime indicators with limited policing bias, fairness remediation may focus more on thresholds and governance rather than data removal (A5, A7).
# Question 2: Does the vendor provide a formal model card and a documented fairness assessment, including calibration by group and equalized odds analyses?
# - Plausible answer implications:
#   - If not, initiate binding contractual requirements for fairness testing, independent audits, and model-card disclosures (A9, A3, A11).
#   - If yes but with limited granularity, demand more rigorous, public-facing dashboards and independent audit validation (A11, A3).
# Question 3: What safeguards exist around human-in-the-loop decisions, and how are high-risk predictions handled in practice?
# - Plausible answer implications:
#   - If safeguards are weak, implement immediate A1 safeguards and strengthen deployment policy (A1, A7).
#   - If safeguards are strong, focus on governance improvements and more robust monitoring to ensure consistent human oversight (A7, A11).
# Question 4: What data-sharing and privacy protections apply to data used for audits and model evaluation, and who can access them?
# - Plausible answer implications:
#   - If access is too restricted, push for independent audits with legally defined data access windows and redacted data, per A3 and A11.
#   - If access is already appropriate, ensure ongoing transparency via public dashboards and annual audit reports (A8, A11).
# Question 5: What remedies exist if disparities persist after remediation (e.g., pause, re-engineering, or reallocation of resources)?
# - Plausible answer implications:
#   - If remedies exist and are actionable (A12), prepare for contingent actions; if remedies are weak or ambiguous, advocate for a governance framework with explicit triggers and public reporting (A12, A11, A8).
#
# 6) Confidence levels and key uncertainties for major recommendations
# - Immediate safeguards (A1): Confidence high; risk of emergency response delays is manageable with clear guidelines for urgent scenarios. Uncertainty: how best to define “high-risk” conditions for automatic human review.
# - Data lineage and governance (A2): Confidence high; essential for traceability. Uncertainty: comprehensiveness across all data sources; possible unidentified data flows.
# - Independent bias/fairness audit (A3): Confidence high; foundational for credibility. Uncertainty: scope of access and potential confidentiality constraints.
# - Debias training data (A4): Confidence medium-high; can reduce historical bias but may impact predictive performance. Uncertainty: which features are truly causal versus proxies; risk of over-correction.
# - Calibration and thresholding (A5): Confidence high; directly addresses fairness across groups. Uncertainty: optimal trade-offs between fairness and accuracy in different contexts.
# - Drift detection and feedback loop mitigation (A6): Confidence medium-high; feasible with modern monitoring, but effectiveness depends on data availability and timely model retraining.
# - Deployment governance (A7): Confidence high; operationally critical to ensure appropriate use. Uncertainty: balance between staffing and responsiveness; potential slowdowns in urgent responses.
# - Community engagement (A8): Confidence high; improves trust and legitimacy. Uncertainty: long-term engagement effects and possible politicization.
# - Vendor policy reform (A9): Confidence high; aligns incentives. Uncertainty: vendor capacity to comply; contract negotiation complexity.
# - Public transparency (A10): Confidence medium-high; enhances accountability but must protect privacy. Uncertainty: how much detail can be publicly shared without compromising security.
# - Ongoing independent monitoring (A11): Confidence high; essential for accountability. Uncertainty: funding sustainability; independence maintenance over time.
# - Contingency plan (A12): Confidence high; provides a clear path to protection if remediation stalls. Uncertainty: political and operational feasibility of pausing deployments.
#
# What the council should do now, and why
# - Immediately tighten governance and safeguards (A1–A3): Establish human oversight, halt unreviewed automated actions, and begin an independent bias/audit baseline. This reduces risk of ongoing harms while you work on longer-term remediation.
# - Commission independent audits (A3) and begin data lineage work (A2): These steps identify root causes and establish a credible road map for remediation; they are foundational for all subsequent actions.
# - Initiate bias correction and fairness calibration (A4–A5): Debias training data and recalibrate risk scores across groups to reduce disparities without sacrificing public safety, as much as possible.
# - Establish community engagement and oversight (A8) and strengthen vendor accountability (A9): Build legitimacy and ensure that the system reflects community values and legal obligations.
# - Implement ongoing monitoring and an independent monitoring framework (A11): Ensure sustained accountability and continuous improvement; publish transparent reports (A10) to maintain trust.
# - Prepare for a contingency pause or re-engineering if targets aren’t met (A12): Demonstrates that civil-rights protections are paramount and provides a clear exit pathway if remediation stalls.
#
# Key precedents, principles, and empirical grounding
# - Disparities in predictive policing documented in Lum & Isaac (2016), ProPublica COMPAS analysis (2016), and follow-up critiques; highlight that data and societal bias can manifest in algorithmic outputs.
# - Fairness impossibility results (Kleinberg, Mullainathan, Raghavan; Kleinberg et al., 2016, 2017) showing that equalizing all fairness metrics simultaneously is generally impossible when base rates differ; the framework here uses multiple metrics and explicit trade-offs rather than a single “perfect” metric.
# - Barocas & Selbst (2016) on bias in algorithmic decision-making and the necessity of governance, transparency, and human oversight.
# - NIST AI RMF and related governance literature emphasize risk management, transparency, accountability, and independent auditing as core pillars for responsible AI in public sector use.
#
# Confidence statements and uncertainties
# - The strongest action cluster (A1–A3, A7–A9) has high confidence because it directly reduces the likelihood of ongoing harm, creates governance mechanisms, and compels vendors to align with fairness and transparency obligations.
# - The data- and model-centric actions (A4–A6) depend on data quality and the ability to disentangle causality; they are likely to yield improvements but require careful implementation to avoid unintended performance losses.
# - Community engagement (A8) is essential for legitimacy; however, its effectiveness depends on sustained commitment, resource allocation, and the willingness of residents to participate meaningfully.
# - The long-term monitoring (A11) and transparency (A10) are essential but rely on sustained funding and political support.
# - The contingency option (A12) is prudent but may carry political and operational risk if invoked.
#
# Executive recommendation: what the council should do now
# - Approve an immediate, tightly scoped set of safeguards (A1) and commission an independent bias/fairness audit (A3) while initiating data governance work (A2). This provides immediate risk reduction and a credible baseline.
# - Simultaneously begin fairness calibration (A5) and establish a deployment governance framework (A7) to ensure any future use of predictions is context-aware and human-in-the-loop.
# - Launch a Community Advisory Board (A8) and contract a formal vendor reform path (A9) to ensure civil-rights protections and transparency.
# - Establish ongoing independent monitoring (A11) with quarterly public reports (A10) to maintain accountability and continuous improvement.
# - If, after 12 months, disparities persist beyond agreed thresholds, activate the contingency pause or re-engineering plan (A12) and reassess the system’s role in public safety.
#
# Final note
# - The city should recognize that fairness and safety are not binary choices but a spectrum of trade-offs. The recommended plan emphasizes governance, transparency, independent assessment, and community involvement as the pillars for restoring equity and public trust while preserving legitimate crime prevention goals. The actions are designed to be implementable within a 12-month frame, with a clear auditable path and measurable milestones.
#
# Appendix: Suggested metrics to track (examples)
# - Disparity metrics: disparate impact ratio (minority vs nonminority positive rate), equalized odds gap (TPR/FPR differences by group), calibration slope by group.
# - Predictive performance: AUC/ROC by group, Brier score overall and by group.
# - Process metrics: time from prediction to action, number of high-risk predictions reviewed by humans, number of interventions deployed per month.
# - Governance metrics: number of audit findings resolved, vendor compliance incidents, community meeting attendance and sentiment, data access requests fulfilled.
#
# If you would like, I can tailor the actions, timelines, and metrics to the city’s existing budgets, governance structures, and vendor contracts, and provide a one-page executive briefing for council members.
#
# # Response from competitor 2
#
# # PREDICTIVE POLICING DISPARITY: COMPREHENSIVE COUNCIL REPORT
#
# ## Prepared for the City Council | Independent Consultant Assessment
#
# ---
#
# > **Executive Summary**
# >
# > This report presents findings and recommendations regarding demonstrated racial and geographic disparities in the city's AI-based predictive policing system. The evidence base for algorithmic bias in predictive policing is substantial and growing; disparity in this system is neither surprising nor inevitable, but it demands structured, urgent response. I recommend the council immediately suspend autonomous decision-making authority vested in the system, establish independent oversight, and pursue a 12-month remediation plan detailed herein. The cost of inaction—continued civil rights harm, litigation exposure, community trust erosion, and likely federal scrutiny—substantially exceeds the cost of remediation. My confidence in the core diagnosis is high; my confidence in specific technical fixes is moderate, contingent on answers to factual questions identified in Section VI.
#
# ---
#
# ## TABLE OF CONTENTS
#
# 1. Causes of Disparity: Technical and Non-Technical
# 2. 12-Month Prioritized Remediation Plan
# 3. Action-by-Action Impact and Resource Analysis
# 4. Independent Audit Protocol
# 5. Principled Framework for Balancing Accuracy, Safety, and Civil Rights
# 6. Key Factual Questions for City Officials and Vendors
# 7. Immediate Recommendations and Rationale
# 8. References and Precedents
#
# ---
#
# ## SECTION I: CAUSES OF DISPARITY — TECHNICAL AND NON-TECHNICAL
#
# Understanding *why* the system produces disparate outcomes is essential before prescribing solutions. The causes are almost certainly multiple, interactive, and mutually reinforcing. I distinguish seven categories below.
#
# ### 1.1 Technical Causes
#
# #### 1.1.1 Biased Training Data (Historical Crime Records)
#
# **What it is:** The model was trained on historical arrest, stop, citation, or crime report data that itself reflects prior discriminatory policing patterns.
#
# **Why it matters:** If police historically concentrated enforcement in minority neighborhoods—whether due to explicit policy, implicit bias, or political decisions—arrest and citation records will overrepresent those neighborhoods even if underlying criminal behavior is distributed differently across the city. Training a model on this data does not reveal ground truth about crime; it reveals ground truth about *prior police behavior*. The model then predicts where police made arrests, not necessarily where crime occurs. This is sometimes called the "dirty data" problem, documented systematically by researchers including Rashida Richardson and colleagues (2019) in their examination of "dirty data" cities.
#
# **Confidence this is present:** High. Nearly every predictive policing deployment using historical crime data is susceptible to this problem. The observed disparity is consistent with this mechanism.
#
# #### 1.1.2 Label Bias
#
# **What it is:** The outcome variable (the "label") the model is trained to predict is itself a biased proxy for the true phenomenon of interest.
#
# **Why it matters:** Models typically predict "reported crime," "arrests," or "calls for service" rather than actual crime incidence. These labels are differentially generated: a robbery in a wealthy neighborhood is more likely to be called in, investigated, and result in an arrest than an equivalent act in a neighborhood where residents distrust police or where police resources are thinner. If the label is "arrests" rather than "crimes," the model learns to predict enforcement intensity, not safety risk. This distinction—between *crime* and *detected crime*—is foundational to understanding algorithmic bias in criminal justice (Lum and Isaac, 2016, demonstrated this explicitly using drug use data in Oakland).
#
# **Confidence this is present:** High.
#
# #### 1.1.3 Feedback Loops (Performative Prediction)
#
# **What it is:** The model's predictions influence where police patrol, which generates more arrests in predicted locations, which are fed back as training data, which reinforces the original predictions in a self-amplifying cycle.
#
# **Why it matters:** This is arguably the most dangerous technical mechanism because it compounds over time. Even a model with modest initial bias can produce extreme disparities after several feedback cycles. Research by Ensign and colleagues (2018) formally modeled this dynamic and demonstrated that feedback loops in predictive policing can drive patrol allocation toward a fixed point that bears little relationship to underlying crime distribution. The system becomes, in effect, a self-fulfilling prophecy.
#
# **Confidence this is present:** High if the model's outputs are used to direct patrol resources and the resulting enforcement data is fed back into model retraining. This is
#
# # Response from competitor 3
#
# **To:** City Council
# **From:** Independent Consultant
# **Date:** October 26, 2023
# **Subject:** Report on Predictive Policing System Disparities & Remediation Plan
#
# ---
#
# ### **Executive Summary**
#
# Our audit confirms the AI-based predictive policing system disproportionately targets minority neighborhoods. This disparity arises from a combination of **technical flaws** (biased training data, label bias, feedback loops) and **non-technical factors** (historical policing patterns, socio-economic confounders, deployment decisions). Left unaddressed, the system risks exacerbating inequality, eroding community trust, and violating civil rights. This report provides a causal analysis, a 12-month remediation plan, an independent audit protocol, a principled trade-off framework, and key questions for officials. **I recommend the council immediately suspend the system’s use for patrol decisions and initiate the proposed remediation plan.**
#
# ---
#
# ### **1. Causes of Disparity**
#
# #### **Technical Causes**
# - **Biased Training Data:** Historical crime data reflect over-policing of minority neighborhoods (e.g., higher arrest rates for low-level offenses), embedding past bias into predictions (*“garbage in, garbage out”*).
# - **Label Bias:** Using arrests or reported crimes as “crime” labels conflates crime prevalence with policing intensity. This is a well-documented source of bias (e.g., Lum & Isaac, 2016).
# - **Feedback Loops:** Predicted hotspots lead to more patrols, which generate more recorded incidents, reinforcing future predictions (a “self-fulfilling prophecy”).
# - **Deployment Decisions:** Thresholds for “high risk” may be set without fairness considerations, amplifying disparities.
#
# #### **Non-Technical Causes**
# - **Policing Practices:** Resource allocation, officer discretion, and community reporting rates differ across neighborhoods.
# - **Socio-Economic Confounders:** Poverty, density, and unemployment correlate with both minority status and some crime types—the system may proxy race via these variables.
# - **Vendor Contract & Oversight:** Lack of transparency in proprietary algorithms, absence of fairness constraints in procurement.
#
# ---
#
# ### **2. 12-Month Remediation Plan**
#
# | Priority | Action | Timeline | Resources Needed | Expected Impact on Disparity/Public Safety | Unintended Consequences/Risks |
# |----------|--------|----------|------------------|--------------------------------------------|-------------------------------|
# | **1. Immediate Safeguards** | Suspend system for patrol allocation; retain for internal analysis only. | Week 1 | Legal review, IT patch. | Halts amplification of bias; short-term uncertainty in patrol planning. | Officer pushback; potential temporary rise in response times. |
# | **2. Data & Model Audit** | Commission independent audit of training data, labels, and model outputs (see Section 4). | Months 1–3 | $80K–$120K for auditors; data engineer (city staff). | Identifies specific bias sources; informs model redesign. | Vendor resistance; may reveal deeper systemic biases. |
# | **3. Community Engagement** | Form oversight board with community reps, public defenders, civil rights advocates. | Months 1–12 (ongoing) | 0.5 FTE coordinator; stipends for community members. | Builds trust, ensures accountability, informs fairness criteria. | Board may lack technical expertise; potential for divisiveness. |
# | **4. Model & Process Redesign** | Redesign system with fairness constraints (e.g., demographic parity, equalized FPR), use alternative data (e.g., 911 calls only), and implement “fairness through awareness” (Dwork et al., 2012). | Months 4–9 | Data scientists (2 FTE), vendor renegotiation ($150K–$300K). | Reduces disparity; may slightly reduce accuracy for majority groups. | Trade-offs between fairness/accuracy; requires careful validation. |
# | **5. Policy & Contract Changes** | Update procurement to require fairness reports, transparency, and city ownership of data/models. | Months 6–12 | Legal, procurement staff. | Prevents future vendor lock-in and black-box systems. | Higher upfront costs; vendors may resist. |
# | **6. Pilot & Monitor** | Pilot revised system in limited districts with pre-specified fairness thresholds. | Months 10–12 | Patrol coordination, monitoring team. | Allows real-world testing of fairness/accuracy trade-offs. | Possible community skepticism even with improvements. |
#
# ---
#
# ### **3. Action Details & Confidence**
#
# - **Immediate Suspension:** *High confidence* based on precedent (e.g., NYPD’s early predictive policing issues). Key uncertainty: contractual penalties with vendor.
# - **Independent Audit:** *High confidence*; necessary for diagnosing specific bias. Uncertainty: data accessibility.
# - **Community Oversight Board:** *Medium confidence*; critical for legitimacy, but effectiveness depends on representation and authority.
# - **Model Redesign:** *Medium confidence*; technical solutions exist but require careful implementation to avoid other harms.
#
# ---
#
# ### **4. Independent Audit Protocol**
#
# **Objective:** Detect disparate harms in predictions vs. outcomes.
#
# **Data Required:**
# - Model predictions (by location/demographic).
# - Ground-truth crime data (victimization surveys, 911 calls).
# - Patrol records (stops, arrests, use of force).
# - Demographic data (census, neighborhood composition).
#
# **Statistical Tests:**
# - **Disparate Impact Ratio:** Compare prediction rates across racial groups.
# - **Error Rate Analysis:** False positive/negative rates by group.
# - **Causal Tests:** Instrumental variables or difference-in-differences to assess feedback loops.
#
# **Acceptable Thresholds:**
# - 80% rule (disparate impact ratio ≥0.8) for initial screening.
# - Statistical significance (p<0.05) for error rate differences.
# - **Action Trigger:** Any violation requires mitigation before redeployment.
#
# **Auditor Independence:**
# - Third-party selection by council + community board.
# - Full transparency: public report, code, and data (where privacy-safe).
#
# ---
#
# ### **5. Principled Trade-Off Framework**
#
# Council should adopt a **“Fairness, Accountability, and Transparency”** framework:
#
# 1. **Operationalize Fairness:** Choose a fairness metric (e.g., equalized false positive rates) based on community input and legal advice. Different definitions (e.g., demographic parity vs. equalized odds) have different trade-offs (Kleinberg et al., 2017).
# 2. **Accept Accuracy Reductions:** If needed, prioritize reducing disparities over marginal gains in overall prediction accuracy. Precedent: Berkeley’s dropped predictive policing due to equity concerns.
# 3. **Monitor Outcomes:** Track both crime rates and community trust metrics (surveys, complaint rates). Use control districts without the system for comparison.
# 4. **Decision Rule:** System redeployment only if it meets pre-agreed fairness thresholds and does not increase disproportionate stops/arrests.
#
# ---
#
# ### **6. Top Five Factual Questions for City/Vendor**
#
# 1. **“What specific crime data and labels were used to train the model?”**
#    - *If arrest data only:* Urgent need to switch to victimization data.
#    - *If mixed sources:* Audit label definitions for bias.
#
# 2. **“How are model predictions translated into patrol decisions (thresholds, human override)?”**
#    - *If fully automated:* Immediate need for human-in-the-loop.
#    - *If discretionary:* Assess officer training and guidelines.
#
# 3. **“What fairness tests were conducted before deployment, and what disparities were found?”**
#    - *If none:* Indicates vendor negligence; consider contract termination.
#    - *If tests showed disparities but were ignored:* Need policy changes to mandate fairness.
#
# 4. **“What is the contractual exit cost and data ownership status?”**
#    - *If high exit cost:* Phase out while developing in-house capacity.
#    - *If city owns data/model:* More flexibility for redesign.
#
# 5. **“What is the historical disparity in police stops/arrests by neighborhood, independent of the AI system?”**
#    - *If high:* System may be amplifying existing bias; need broader policing reform.
#    - *If low:* Suggests technical flaws dominate.
#
# ---
#
# ### **Recommendation**
#
# **The council should immediately suspend the system’s operational use, commission an independent audit, and establish a community oversight board.** These steps halt harm, diagnose root causes, and ensure community voice in remediation. The proposed 12-month plan balances urgency with feasibility, addressing both technical and systemic factors. Continuing without intervention risks legal liability, deepened distrust, and perpetuation of inequity.
#
# ---
# **Confidence:** High for immediate suspension and audit; medium for long-term redesign due to vendor and data uncertainties.
# **Citations:** Lum & Isaac (2016), Dwork et al. (2012), Kleinberg et al. (2017), Berk et al. (2021) on fairness trade-offs.
#
# # Response from competitor 4
#
# **Report: Remediation Plan for AI‑Based Predictive Policing System**
#
# **I. Introduction**
#
# The city's AI-based predictive policing system has been shown to disproportionately target minority neighborhoods, raising concerns about systemic bias and potential harm to communities of color. This report aims to provide a comprehensive analysis of the plausible causes of the disparity and proposed a prioritized 12-month remediation plan to address these issues.
#
# **II. Causes of Disparity**
#
# Technical causes:
#
# 1. **Biased training data**: Inadequate or skewed training datasets can perpetuate existing biases.
# 2. **Label bias**: Labelling patterns in historical crime data may reflect discrimination against minority groups.
# 3. **Feedback loops**: The system's self-reinforcing nature can amplify biased assumptions and predictions.
#
# Non-technical causes:
#
# 1. **Policing practices**: Aggressive policing tactics, racial profiling, and over-policing of minority neighborhoods contribute to the disparity.
# 2. **Socio-economic confounders**: Systematic differences in poverty rates, education levels, and employment opportunities across neighborhoods can skew crime data.
# 3. **Deployment decisions**: The system's algorithms are deployed without adequate consideration for community context, exacerbating biases.
#
# **III. Remediation Plan**
#
# A. Immediate Safeguards (Months 1-3)
#
# 1. **Data audit**: Conduct a thorough review of training data to identify patterns and biases (Estimated impact on disparity: −20%).
# 2. **System auditing**: Perform regular checks for updates, anomalies, and bias-related issues.
# 3. **Community outreach**: Engage in community forums to raise awareness and establish a dialogue on AI-based policing.
#
# B. Data and Model Updates (Months 4-6)
#
# 1. **Model adjustments**: Implement data-driven updates to reduce bias in algorithms ($100,000 - $300,000).
# 2. **Training dataset refresh**: Regularly update training datasets to reflect changing community demographics.
# 3. **External validation**: Engage with independent experts for model testing and validation.
#
# C. Deployment and Decision-Making Changes (Months 7-9)
#
# 1. **Algorithmic adjustments**: Implement algorithms that prioritize contextual understanding over simplistic rules ($150,000 - $400,000).
# 2. **Deployment guidelines**: Develop and deploy guidelines to address potential biases in deployment decisions.
# 3. **Training for officers**: Provide training on AI-based policing tools and their limitations.
#
# D. Community Engagement and Oversight (Months 10-12)
#
# 1. **Community advisory board**: Establish an independent community board to monitor the system's performance.
# 2. **Regular audits**: Perform quarterly audits to assess disparities and adjust mitigation strategies as needed.
# 3. **Policy oversight**: Conduct regular review of policy changes aligning with community feedback and expert input.
#
# E. Policy and Contractual Changes (Months 12-18)
#
# 1. **Racial bias policy**: Develop a city-wide policy on AI-based policing, emphasizing fairness and equity ($200,000 - $500,000).
# 2. **Vendor contract reviews**: Conduct regular reviews of contracts with vendors to ensure compliance with bias mitigation measures.
# 3. **Transparency reporting**: Establish clear reporting guidelines for transparency regarding the system's performance.
#
# **IV. Independent Audit Protocol**
#
# A. Data Collection:
#
# 1. Disaggregate crime data by neighborhood type and demographic groupings.
# 2. Analyze deployment patterns, response rates, and outcomes (e.g., arrests, convictions).
#
# B. Statistical and Causal Tests:
#
# 1. Apply regression analysis to assess disparities in historical crime data.
# 2. Employ causality tests to determine whether algorithmic predictions lead to distinct changes in policing behaviors.
#
# C. Acceptable Thresholds for Action:
#
# 1. Establish benchmarks for disparity reduction targets (e.g., 15%); adjust these as necessary.
# 2. Engage with local experts and civil society organizations to set thresholds for bias recognition.
#
# D. Auditor Independence and Transparency
#
# 1. Ensure the independent auditor has no direct affiliation with vendors or internal stakeholders.
# 2. Implement a structured process for sharing findings, recommendations, and system evaluation data with relevant city departments, community boards, and external stakeholders.
#
# **V. Principles for Tradeoff Between Predictive Accuracy, Public Safety, and Civil-Rights Protections**
#
# To balance predictive accuracy, public safety, and civil-rights protections:
#
# 1. **Data-driven decision-making**: Leverage objective data to underpin policing decisions.
# 2. **Algorithmic explainability**: Ensure algorithms provide robust explanations for recommendations.
# 3. **Community-centric approaches**: Prioritize contextual understanding and feedback from affected communities.
#
# These core principles inform adjustments in model deployment, decision-making processes, and ongoing community engagement throughout the project timeline.
#
# **VI. Top Five Questions to Ask City Officials or Vendors**
#
# 1. What data sources were used to develop the predictive policing system?
# 2. How has the system been validated against diverse training datasets, including samples representing minority populations?
#
# **VII. Conclusion and Confidence Level**
#
# This report emphasizes a 12-month remediation plan focused on immediate safeguards, ongoing audits, strategic software updates, deployment changes, and community oversight. To ensure our recommendations are effective, I set high confidence levels across most measures. However, uncertainties related to data availability, model explanations, vendor compliance with regulations, and societal perceptions of AI must be addressed.
#
# The best path forward is that the council engages in this collaborative framework with local stakeholders to identify specific questions and address emerging concerns.
#
# We recommend:
#
# 1. The city implement these measures to address disparity.
# 2. Regular community engagement ensures buy-in for systemic improvements.
#
# These priorities will allow the system to improve its performance and prioritize protection over prediction

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 4 competitors.
# Each model has been given this question:
#
# You are an independent consultant asked to produce a single, council-ready report for a mid-sized city whose AI-based predictive policing system has been shown to disproportionately target minority neighborhoods; in that report, please do all of the following: (1) identify and clearly distinguish the plausible technical and non-technical causes of the disparity (e.g., biased training data, label bias, feedback loops, policing practices, socio-economic confounders, deployment decisions); (2) propose a prioritized, feasible 12‑month remediation plan that includes immediate safeguards, data and model audits, changes to deployment and decision-making processes, community engagement and oversight mechanisms, and policy or contractual changes with vendors; (3) for each action in the plan, estimate the expected impact on disparity and public safety, the human and financial resources required, an implementation timeline, and the most likely unintended consequences or risks; (4) design a protocol for an independent audit that would detect whether the system continues to produce disparate harms, specifying what data to collect, what statistical and causal tests to run, acceptable thresholds for action, and how to ensure auditor independence and transparency; (5) explain a principled framework the council can use to trade off predictive accuracy, public safety, and civil‑rights protections (including how to operationalize fairness criteria, when to accept reductions in accuracy, and how to monitor outcomes over time); and (6) list the top five specific factual questions you would ask city officials or vendors to refine your recommendations, and explain how different plausible answers to each would change your prioritized actions; cite relevant principles, empirical findings or precedents where appropriate, and for each major recommendation state your confidence level and the key uncertainties that could alter your advice—what do you recommend the council do now, and why?
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Council-ready report: Addressing disparities in an AI-based predictive policing system
#
# Date: [Insert date]
#
# Executive summary
# - Problem: An AI-driven predictive policing system is disproportionately flagging minority neighborhoods, raising civil-rights concerns and eroding public trust.
# - Core finding: Disparities arise from a mix of technical causes (biased historical data, label bias, feedback loops, feature leakage, data quality gaps) and non-technical causes (policing practices, deployment choices, socio-economic confounders, governance and contractor practices).
# - Plan: A 12-month remediation program combining immediate safeguards, data/model audits, deployment/process changes, community oversight, and binding vendor policy changes; plus an independent audit protocol and a principled framework to balance accuracy, public safety, and civil rights.
# - Outcome sought: Reduced bias in predictions while preserving or improving public safety, with transparent, auditable processes and robust community oversight.
#
# 1) Plausible causes of disparity: technical vs. non-technical
# A. Technical causes
# - Biased training data
#   - Historical policing records reflect prior enforcement biases (e.g., over-policing in minority neighborhoods), creating biased predictive signals.
# - Label bias
#   - The target variable (crime labels, arrests, gun detections) may reflect enforcement practices and not true underlying risk, injecting label bias.
# - Feedback loops
#   - Predicted risk drives policing activity in certain areas, generating more incident data there and reinforcing the model’s belief that those areas are high risk (self-fulfilling loop).
# - Data quality and representation gaps
#   - Missing data, under-reporting in some communities, or insufficient coverage of certain geographies skew model training.
# - Feature biases and leakage
#   - Proximity to police facilities, prior stop frequencies, or census-geography proxies can act as proxies for sensitive attributes; models may learn spurious correlations with protected groups.
# - Model design choices
#   - Complexity or training procedures that optimize overall accuracy at the expense of fairness; failure to calibrate scores across groups.
# - Temporal drift and nonstationarity
#   - Crime patterns shift; models trained on older data misrepresent current risk, potentially differentially affecting groups.
# B. Non-technical causes
# - Policing practices and policy
#   - Law enforcement priorities, discretionary stops, or geofenced deployment that concentrate effort in particular neighborhoods.
# - Deployment decisions and governance
#   - Where and how predictions influence action (e.g., early-warning flags vs. reactive discretion) shapes how disparities translate into outcomes.
# - Socio-economic confounders
#   - Structural inequalities (poverty, housing, education, limited legitimate opportunities) correlate with crime metrics and neighborhood demographics, confounding causal interpretation.
# - Vendor and procurement factors
#   - Contracts that emphasize predictive accuracy without fairness requirements; opaque model provenance; lack of independent audits.
# - Community trust and data sharing
#   - Under-resourced communities may have lower engagement or reporting rates, affecting data representativeness.
#
# Notes on causality and interpretation
# - Many causes are interdependent. For example, biased training data + feedback loops + policing deployment choices can magnify disparities even when the underlying model is technically well-behaved.
# - Distinguishing between short-term remediation (e.g., threshold re-calibration) and long-term systemic reform (e.g., governance reforms, data collection improvements) is essential.
#
# 2) A prioritized, feasible 12-month remediation plan
# Guiding principles
# - Immediate safeguards first: ensure human review, prohibit automatic discretionary actions based solely on risk scores, and place a cap on high-stakes decisions driven by the model.
# - Data and model transparency: audits, audits, audits—internal and independent.
# - Community oversight: establish protections and channels for affected communities; publish aggregate metrics and progress.
# - Vendor accountability: contractually bind fairness, transparency, and audit rights.
#
# 12-month plan (action-by-action overview; owners in parentheses)
# A1. Immediate safeguards for deployment (0–1 month)
# - What: Prohibit automatic enforcement actions solely based on model output; require a human-in-the-loop for high-risk decisions; implement a “watchlist” to flag anomalous scores for review.
# - Expected impact: Moderate reduction in excessive reliance on predictions; limit potential harm in the near term.
# - Resources: Policy staff, field supervisors, IT to enforce controls.
# - Timeline: 0–4 weeks.
# - Risks: Slower response in emergencies; potential backlog; need clear guidelines for human decision-makers.
# - Confidence: High; uncertainties relate to operational enforcement.
#
# A2. Enforce data lineage and governance (0–2 months)
# - What: Inventory data sources, define data lineage, retention, and access controls; map which features derive from historical policing behavior vs. real-time context.
# - Expected impact: Improves ability to diagnose bias sources; reduces leakage of biased signals.
# - Resources: Data governance team; IT security; legal review.
# - Timeline: 0–8 weeks.
# - Risks: Resource-intensive; potential pushback from data producers.
# - Confidence: High.
#
# A3. Independent bias and fairness audit (0–3 months)
# - What: Commission an independent audit to assess fairness metrics (calibration by group, equalized odds, demographic parity), identify proxies for sensitive attributes, review data sampling and targets.
# - Expected impact: Establish baseline and concrete remediation targets; increase trust.
# - Resources: External audit firm, internal liaison.
# - Timeline: RFP in month 0–1; audit in months 1–3.
# - Risks: Auditor access to data; confidentiality considerations.
# - Confidence: High.
#
# A4. Debias training data and feature engineering (1–4 months)
# - What: Apply techniques to mitigate bias in training data (reweighting, resampling, causal modeling where feasible), remove or limit use of problematic proxies; consider using counterfactual fairness or causal risk models.
# - Expected impact: Reduce historical bias transmission; improve fairness metrics.
# - Resources: Data science team; compute; possible external expertise.
# - Timeline: 1–4 months.
# - Risks: Potential reduction in overall predictive performance; need to monitor for unintended effects.
# - Confidence: Medium-High.
#
# A5. Calibration and thresholding for equalized outcomes (2–5 months)
# - What: Re-calibrate scores by demographic group; adjust decision thresholds to achieve specified fairness objectives (e.g., equalized false positive rates or equal misclassification costs) while maintaining acceptable overall accuracy.
# - Expected impact: Direct reduction in disparate impacts; more uniform operation across groups.
# - Resources: Data scientists; policy/operations teams; governance oversight.
# - Timeline: 2–6 months.
# - Risks: Trade-off with accuracy; threshold drift over time needs ongoing monitoring.
# - Confidence: High.
#
# A6. Mitigate feedback loops with drift detection (2–6 months)
# - What: Implement monitoring for data drift and model drift; insert mechanisms to decouple current policing activity from model-generated data where feasible; refresh training data with more representative samples.
# - Expected impact: Stability against self-reinforcing biases; better long-run equity.
# - Resources: Data science + engineering; monitoring dashboards.
# - Timeline: 2–6 months.
# - Risks: Complexity of measuring drift in criminal data; requires ongoing maintenance.
# - Confidence: Medium-High.
#
# A7. Deployment governance and use-case refinement (3–7 months)
# - What: Define clear use cases for predictions (e.g., resource allocation planning vs. operational preemption); restrict areas or situations where scores drive decisions; require human decision-makers to consider context.
# - Expected impact: Reduces overbroad application of predictions; aligns with civil-rights safeguards.
# - Resources: Policy, legal, operations.
# - Timeline: 3–7 months.
# - Risks: Potential reduction in some predictive benefits; need careful communication with staff.
# - Confidence: High.
#
# A8. Community engagement and oversight mechanisms (4–8 months)
# - What: Establish Community Advisory Board (CAB), public dashboards with aggregate metrics, town halls, and a public data access policy for aggregated results; ensure accessible, multilingual communications.
# - Expected impact: Increased legitimacy, improved data quality through local feedback; stronger social license to operate.
# - Resources: Community relations; communications; data team.
# - Timeline: 4–8 months.
# - Risks: Potential politicization; must maintain privacy and security controls.
# - Confidence: High.
#
# A9. Vendor policy and procurement reforms (4–12 months)
# - What: Include fairness-by-design requirements in contracts; require model cards, audit rights, data provenance, versioning, and remediation plans; specify penalties for noncompliance; require third-party audits at defined intervals.
# - Expected impact: Structural incentive for fairness and transparency; clear accountability.
# - Resources: Legal, procurement, policy teams; potential legal reviews.
# - Timeline: 4–12 months.
# - Risks: Vendor resistance; negotiation complexity.
# - Confidence: High.
#
# A10. Public-facing transparency and educational materials (5–12 months)
# - What: Publish high-level model governance, fairness metrics, and remediation steps; avoid exposing sensitive details that could enable manipulation; provide resources for community members to understand policing changes.
# - Expected impact: Maintains trust and civic engagement; reduces speculation.
# - Resources: Communications; privacy/compliance.
# - Timeline: 5–12 months.
# - Risks: Privacy and security concerns; risk of misinterpretation.
# - Confidence: Medium-High.
#
# A11. Ongoing independent monitoring framework (6–12+ months)
# - What: Establish continuous independent evaluation, with quarterly public reports; annual full audit; data access controls for auditors; integrate independent feedback loops into governance.
# - Expected impact: Sustained accountability and long-term improvement.
# - Resources: Independent auditor commitments; governance body; IT for data access.
# - Timeline: Launch by month 6; ongoing thereafter.
# - Risks: Sustained funding and independence; confidentiality.
# - Confidence: High.
#
# A12. Contingency pause or re-engineering if targets not met (12 months)
# - What: If disparity metrics remain outside targets after full remediation window, pause deployment in affected geographies and pivot to non-predictive approaches or comprehensive reforms; re-evaluate system design.
# - Expected impact: Strong signal that civil-rights protections take priority; avoids perpetuating harm.
# - Resources: Governance and budget approvals.
# - Timeline: Triggered at 12 months if needed.
# - Risks: Public safety concerns; political ramifications.
# - Confidence: High; uncertainty about feasible alternatives.
#
# How these actions map to impact and resources
# - Impact on disparity: Most direct reductions from A3, A5, A6, A7, A9, A11; measurable improvements expected within 6–12 months if implemented rigorously.
# - Impact on public safety: Maintained or improved through careful calibration, human-in-the-loop processes, and governance; risk of short-term dip if thresholds restrict some predictive utility; mitigated by improved data quality and targeted interventions.
# - Human resources: 4–8 FTEs for governance, data science, and policy; external auditors for A3/A11; ongoing vendor management staff; community liaison roles.
# - Financial resources: Budget for audits, software governance tools, potential re-architecture, contract changes, and community engagement activities.
# - Timeline: Phased, with quick wins within 0–3 months (A1–A3) and longer-term governance and vendor changes by 6–12 months (A8–A11). Contingency action (A12) if targets not met.
#
# 3) Independent audit protocol to detect ongoing disparate harms
# Purpose
# - Detect whether the system continues to produce disparate harms and to attribute root causes.
#
# Data to collect (with privacy and legal guardrails)
# - Aggregated, de-identified incident-level data linked to model predictions, outcomes, and geographies (e.g., census tracts or neighborhoods) with time stamps.
# - Predicted risk scores and corresponding real-world outcomes (whether an incident occurred, arrests, or verified crimes).
# - Group-level identifiers allowed by law and policy (e.g., race/ethnicity proxies at aggregate level, or neighborhood-level demographic composition). Use synthetic or grouped data if individual attributes cannot be disclosed.
# - Deployment context data: policing posture in each area, officer density, time-of-day, resource allocation.
#
# Tests and analyses (in a protocol)
# - Fairness tests:
#   - Calibration by group: compare predicted risk to observed outcomes within each group; check calibration slope and intercept per group.
#   - Equalized odds: compare TPR and FPR across groups; ensure gaps are within predefined thresholds (e.g., <= 0.05 difference in TPR and FPR).
#   - Demographic parity (where legally permissible): compare positive prediction rates by group; target disparity <= 0.05 in absolute difference or within 0.8–1.25 ratio range.
# - Causal and quasi-experimental tests:
#   - Propensity score weighting to adjust for socio-economic confounders; examine residual association between group membership and predictions after adjustment.
#   - Difference-in-differences around policy changes to assess whether interventions affect disparities.
#   - Sensitivity analyses for unmeasured confounding in the observed disparities.
# - Robustness and leakage checks:
#   - Feature attribution and SHAP-like explanations to identify proxies for sensitive attributes; remove or constrain problematic features.
#   - Temporal drift analyses to detect shifts in data distribution and model behavior.
# - Validation and governance checks:
#   - Reproducibility: fixed data windows, versioned data, and model cards for each release.
#   - Audit trails: complete logs of data used, features, model versions, predictions, and human actions taken.
#
# Thresholds for action (indicators to trigger remediation)
# - If calibration by group deviates from 1.0 by more than ±0.1 for any group, trigger recalibration and potential feature removal.
# - If equalized odds gaps exceed ±0.05 in TPR or FPR for any group for two consecutive quarterly audits, trigger remediation (A5/A6) and governance review.
# - If demographic parity differences exceed ±0.05 across multiple geographies for two consecutive audits, pause or re-scope deployment in those geographies (A7/A12).
# - If persistent drift is detected without remediation after two cycles, escalate to independent governance body and consider vendor changes (A9/A11).
#
# Auditor independence and transparency
# - Auditing body must be legally and organizationally independent from the city’s policing apparatus and from the vendor.
# - Public summary reports released on a regular cadence; full, detailed reports available to the council and the independent oversight board, with redactions where necessary to protect privacy.
# - Access to data and model artifacts governed by data-sharing agreements, with strict confidentiality and security protocols.
# - Auditor selection: competitive tender, rotation of lead auditors every 3–5 years; annual performance review and public disclosure of qualifications.
# - Transparency: publish model cards, data schemas, and fairness metrics in a publicly accessible dashboard, with user-friendly explanations for non-technical stakeholders.
#
# 4) A principled framework for trading off predictive accuracy, public safety, and civil-rights protections
# Core objective
# - Maximize public safety while meeting explicit civil-rights protections and maintaining accountable governance.
#
# Operationalization steps
# - Define objective function with constraints:
#   - Primary objective: maximize net public safety benefit (e.g., reductions in crime rates, reductions in violent incidents) and minimize harms caused by false positives.
#   - Constraints: maintain fairness thresholds (calibration by group, equalized odds, and, where legally permissible, demographic parity) within specified bounds; require human oversight for high-risk predictions; preserve privacy and civil liberties.
# - Fairness criteria selection (practical guidance):
#   - Use multiple fairness notions to capture different harms; no single metric will satisfy all fairness criteria due to known impossibility results (Kleinberg et al. 2016/2017). Report trade-offs among metrics and justify choices.
#   - Calibrate the model by group so that each group’s observed risk aligns with predicted risk (calibration within groups).
#   - Choose a preferred fairness constraint (e.g., equalized odds or equalized calibration) based on policy priorities and legal requirements; consider multiple models or operating points to illustrate trade-offs.
# - Operational thresholds and accept/reject rules:
#   - If the model’s fairness metrics cannot be brought into alignment without unacceptable losses in predictive utility, constrain usage to non-discretionary, non-actionable predictions for certain contexts; emphasize human-centered decision processes.
#   - Maintain a policy of “no automated discretionary action without human review” for high-risk predictions, especially those that would trigger stops or detentions.
# - Monitoring and learning loop:
#   - Establish quarterly reviews of both accuracy and fairness metrics; adjust thresholds and training data with the independent audit’s recommendations.
#   - Introduce a governance veto on deploying changes that would meaningfully degrade civil-rights protections.
# - Time horizon and signaling:
#   - Short-term operationalization: prioritize constraints and human-in-the-loop processes; demonstrate improvements in fairness metrics within 6–12 months.
#   - Long-term sustainability: embed continuous fairness evaluation in standard practice (A3–A11) and ensure community oversight is ongoing.
#
# Operationalizing fairness and monitoring
# - Use model cards and data sheets for transparency (documentation of data sources, model inputs, performance metrics by group, and limitations).
# - Publish accessible dashboards showing aggregated metrics (crime outcomes, false positives, resource allocation) across geographies and over time.
# - Establish triggers for governance reviews if disparities widen or if performance degrades beyond agreed thresholds.
#
# Key uncertainties and how they could affect recommendations
# - If legal restrictions limit collection of sensitive attributes or group proxies, fairness verification may rely on proxy measures (uncertainties in their validity). Plan alternative proxies and document limitations.
# - If the city cannot attain acceptable fairness thresholds without sacrificing too much predictive accuracy, the framework suggests restricting deployment to non-predictive uses or reducing scope, with public communication and community involvement.
# - If historical crime rates in certain neighborhoods reflect under-reporting or other data issues, fairness tests may overstate disparities; the audit protocol includes causal analyses to address this.
# - Vendor capabilities vary; if a vendor cannot meet fairness-by-design requirements within budget, plan for competitive procurement and longer-term reengineering with phasing to avoid operational disruption.
# - Unintended consequences: tightening safeguards may reduce predictive utility in the short term, potentially affecting legitimate crime prevention efforts; this must be transparently communicated and mitigated with improved data quality and governance.
#
# 5) The top five factual questions to city officials or vendors (and how answers would shift actions)
# Question 1: What data sources feed the predictive model, and to what extent do they reflect policing practices or past enforcement priorities?
# - Plausible answer implications:
#   - If data are heavily biased by past enforcement, treat as a top-priority bias source (A3–A6) requiring data reweighting, removal of biased proxies, and increased emphasis on real-time contextual features; prioritize data governance and audit remediation (A2, A3, A5).
#   - If data reflect broader crime indicators with limited policing bias, fairness remediation may focus more on thresholds and governance rather than data removal (A5, A7).
# Question 2: Does the vendor provide a formal model card and a documented fairness assessment, including calibration by group and equalized odds analyses?
# - Plausible answer implications:
#   - If not, initiate binding contractual requirements for fairness testing, independent audits, and model-card disclosures (A9, A3, A11).
#   - If yes but with limited granularity, demand more rigorous, public-facing dashboards and independent audit validation (A11, A3).
# Question 3: What safeguards exist around human-in-the-loop decisions, and how are high-risk predictions handled in practice?
# - Plausible answer implications:
#   - If safeguards are weak, implement immediate A1 safeguards and strengthen deployment policy (A1, A7).
#   - If safeguards are strong, focus on governance improvements and more robust monitoring to ensure consistent human oversight (A7, A11).
# Question 4: What data-sharing and privacy protections apply to data used for audits and model evaluation, and who can access them?
# - Plausible answer implications:
#   - If access is too restricted, push for independent audits with legally defined data access windows and redacted data, per A3 and A11.
#   - If access is already appropriate, ensure ongoing transparency via public dashboards and annual audit reports (A8, A11).
# Question 5: What remedies exist if disparities persist after remediation (e.g., pause, re-engineering, or reallocation of resources)?
# - Plausible answer implications:
#   - If remedies exist and are actionable (A12), prepare for contingent actions; if remedies are weak or ambiguous, advocate for a governance framework with explicit triggers and public reporting (A12, A11, A8).
#
# 6) Confidence levels and key uncertainties for major recommendations
# - Immediate safeguards (A1): Confidence high; risk of emergency response delays is manageable with clear guidelines for urgent scenarios. Uncertainty: how best to define “high-risk” conditions for automatic human review.
# - Data lineage and governance (A2): Confidence high; essential for traceability. Uncertainty: comprehensiveness across all data sources; possible unidentified data flows.
# - Independent bias/fairness audit (A3): Confidence high; foundational for credibility. Uncertainty: scope of access and potential confidentiality constraints.
# - Debias training data (A4): Confidence medium-high; can reduce historical bias but may impact predictive performance. Uncertainty: which features are truly causal versus proxies; risk of over-correction.
# - Calibration and thresholding (A5): Confidence high; directly addresses fairness across groups. Uncertainty: optimal trade-offs between fairness and accuracy in different contexts.
# - Drift detection and feedback loop mitigation (A6): Confidence medium-high; feasible with modern monitoring, but effectiveness depends on data availability and timely model retraining.
# - Deployment governance (A7): Confidence high; operationally critical to ensure appropriate use. Uncertainty: balance between staffing and responsiveness; potential slowdowns in urgent responses.
# - Community engagement (A8): Confidence high; improves trust and legitimacy. Uncertainty: long-term engagement effects and possible politicization.
# - Vendor policy reform (A9): Confidence high; aligns incentives. Uncertainty: vendor capacity to comply; contract negotiation complexity.
# - Public transparency (A10): Confidence medium-high; enhances accountability but must protect privacy. Uncertainty: how much detail can be publicly shared without compromising security.
# - Ongoing independent monitoring (A11): Confidence high; essential for accountability. Uncertainty: funding sustainability; independence maintenance over time.
# - Contingency plan (A12): Confidence high; provides a clear path to protection if remediation stalls. Uncertainty: political and operational feasibility of pausing deployments.
#
# What the council should do now, and why
# - Immediately tighten governance and safeguards (A1–A3): Establish human oversight, halt unreviewed automated actions, and begin an independent bias/audit baseline. This reduces risk of ongoing harms while you work on longer-term remediation.
# - Commission independent audits (A3) and begin data lineage work (A2): These steps identify root causes and establish a credible road map for remediation; they are foundational for all subsequent actions.
# - Initiate bias correction and fairness calibration (A4–A5): Debias training data and recalibrate risk scores across groups to reduce disparities without sacrificing public safety, as much as possible.
# - Establish community engagement and oversight (A8) and strengthen vendor accountability (A9): Build legitimacy and ensure that the system reflects community values and legal obligations.
# - Implement ongoing monitoring and an independent monitoring framework (A11): Ensure sustained accountability and continuous improvement; publish transparent reports (A10) to maintain trust.
# - Prepare for a contingency pause or re-engineering if targets aren’t met (A12): Demonstrates that civil-rights protections are paramount and provides a clear exit pathway if remediation stalls.
#
# Key precedents, principles, and empirical grounding
# - Disparities in predictive policing documented in Lum & Isaac (2016), ProPublica COMPAS analysis (2016), and follow-up critiques; highlight that data and societal bias can manifest in algorithmic outputs.
# - Fairness impossibility results (Kleinberg, Mullainathan, Raghavan; Kleinberg et al., 2016, 2017) showing that equalizing all fairness metrics simultaneously is generally impossible when base rates differ; the framework here uses multiple metrics and explicit trade-offs rather than a single “perfect” metric.
# - Barocas & Selbst (2016) on bias in algorithmic decision-making and the necessity of governance, transparency, and human oversight.
# - NIST AI RMF and related governance literature emphasize risk management, transparency, accountability, and independent auditing as core pillars for responsible AI in public sector use.
#
# Confidence statements and uncertainties
# - The strongest action cluster (A1–A3, A7–A9) has high confidence because it directly reduces the likelihood of ongoing harm, creates governance mechanisms, and compels vendors to align with fairness and transparency obligations.
# - The data- and model-centric actions (A4–A6) depend on data quality and the ability to disentangle causality; they are likely to yield improvements but require careful implementation to avoid unintended performance losses.
# - Community engagement (A8) is essential for legitimacy; however, its effectiveness depends on sustained commitment, resource allocation, and the willingness of residents to participate meaningfully.
# - The long-term monitoring (A11) and transparency (A10) are essential but rely on sustained funding and political support.
# - The contingency option (A12) is prudent but may carry political and operational risk if invoked.
#
# Executive recommendation: what the council should do now
# - Approve an immediate, tightly scoped set of safeguards (A1) and commission an independent bias/fairness audit (A3) while initiating data governance work (A2). This provides immediate risk reduction and a credible baseline.
# - Simultaneously begin fairness calibration (A5) and establish a deployment governance framework (A7) to ensure any future use of predictions is context-aware and human-in-the-loop.
# - Launch a Community Advisory Board (A8) and contract a formal vendor reform path (A9) to ensure civil-rights protections and transparency.
# - Establish ongoing independent monitoring (A11) with quarterly public reports (A10) to maintain accountability and continuous improvement.
# - If, after 12 months, disparities persist beyond agreed thresholds, activate the contingency pause or re-engineering plan (A12) and reassess the system’s role in public safety.
#
# Final note
# - The city should recognize that fairness and safety are not binary choices but a spectrum of trade-offs. The recommended plan emphasizes governance, transparency, independent assessment, and community involvement as the pillars for restoring equity and public trust while preserving legitimate crime prevention goals. The actions are designed to be implementable within a 12-month frame, with a clear auditable path and measurable milestones.
#
# Appendix: Suggested metrics to track (examples)
# - Disparity metrics: disparate impact ratio (minority vs nonminority positive rate), equalized odds gap (TPR/FPR differences by group), calibration slope by group.
# - Predictive performance: AUC/ROC by group, Brier score overall and by group.
# - Process metrics: time from prediction to action, number of high-risk predictions reviewed by humans, number of interventions deployed per month.
# - Governance metrics: number of audit findings resolved, vendor compliance incidents, community meeting attendance and sentiment, data access requests fulfilled.
#
# If you would like, I can tailor the actions, timelines, and metrics to the city’s existing budgets, governance structures, and vendor contracts, and provide a one-page executive briefing for council members.
#
# # Response from competitor 2
#
# # PREDICTIVE POLICING DISPARITY: COMPREHENSIVE COUNCIL REPORT
#
# ## Prepared for the City Council | Independent Consultant Assessment
#
# ---
#
# > **Executive Summary**
# >
# > This report presents findings and recommendations regarding demonstrated racial and geographic disparities in the city's AI-based predictive policing system. The evidence base for algorithmic bias in predictive policing is substantial and growing; disparity in this system is neither surprising nor inevitable, but it demands structured, urgent response. I recommend the council immediately suspend autonomous decision-making authority vested in the system, establish independent oversight, and pursue a 12-month remediation plan detailed herein. The cost of inaction—continued civil rights harm, litigation exposure, community trust erosion, and likely federal scrutiny—substantially exceeds the cost of remediation. My confidence in the core diagnosis is high; my confidence in specific technical fixes is moderate, contingent on answers to factual questions identified in Section VI.
#
# ---
#
# ## TABLE OF CONTENTS
#
# 1. Causes of Disparity: Technical and Non-Technical
# 2. 12-Month Prioritized Remediation Plan
# 3. Action-by-Action Impact and Resource Analysis
# 4. Independent Audit Protocol
# 5. Principled Framework for Balancing Accuracy, Safety, and Civil Rights
# 6. Key Factual Questions for City Officials and Vendors
# 7. Immediate Recommendations and Rationale
# 8. References and Precedents
#
# ---
#
# ## SECTION I: CAUSES OF DISPARITY — TECHNICAL AND NON-TECHNICAL
#
# Understanding *why* the system produces disparate outcomes is essential before prescribing solutions. The causes are almost certainly multiple, interactive, and mutually reinforcing. I distinguish seven categories below.
#
# ### 1.1 Technical Causes
#
# #### 1.1.1 Biased Training Data (Historical Crime Records)
#
# **What it is:** The model was trained on historical arrest, stop, citation, or crime report data that itself reflects prior discriminatory policing patterns.
#
# **Why it matters:** If police historically concentrated enforcement in minority neighborhoods—whether due to explicit policy, implicit bias, or political decisions—arrest and citation records will overrepresent those neighborhoods even if underlying criminal behavior is distributed differently across the city. Training a model on this data does not reveal ground truth about crime; it reveals ground truth about *prior police behavior*. The model then predicts where police made arrests, not necessarily where crime occurs. This is sometimes called the "dirty data" problem, documented systematically by researchers including Rashida Richardson and colleagues (2019) in their examination of "dirty data" cities.
#
# **Confidence this is present:** High. Nearly every predictive policing deployment using historical crime data is susceptible to this problem. The observed disparity is consistent with this mechanism.
#
# #### 1.1.2 Label Bias
#
# **What it is:** The outcome variable (the "label") the model is trained to predict is itself a biased proxy for the true phenomenon of interest.
#
# **Why it matters:** Models typically predict "reported crime," "arrests," or "calls for service" rather than actual crime incidence. These labels are differentially generated: a robbery in a wealthy neighborhood is more likely to be called in, investigated, and result in an arrest than an equivalent act in a neighborhood where residents distrust police or where police resources are thinner. If the label is "arrests" rather than "crimes," the model learns to predict enforcement intensity, not safety risk. This distinction—between *crime* and *detected crime*—is foundational to understanding algorithmic bias in criminal justice (Lum and Isaac, 2016, demonstrated this explicitly using drug use data in Oakland).
#
# **Confidence this is present:** High.
#
# #### 1.1.3 Feedback Loops (Performative Prediction)
#
# **What it is:** The model's predictions influence where police patrol, which generates more arrests in predicted locations, which are fed back as training data, which reinforces the original predictions in a self-amplifying cycle.
#
# **Why it matters:** This is arguably the most dangerous technical mechanism because it compounds over time. Even a model with modest initial bias can produce extreme disparities after several feedback cycles. Research by Ensign and colleagues (2018) formally modeled this dynamic and demonstrated that feedback loops in predictive policing can drive patrol allocation toward a fixed point that bears little relationship to underlying crime distribution. The system becomes, in effect, a self-fulfilling prophecy.
#
# **Confidence this is present:** High if the model's outputs are used to direct patrol resources and the resulting enforcement data is fed back into model retraining. This is
#
# # Response from competitor 3
#
# **To:** City Council
# **From:** Independent Consultant
# **Date:** October 26, 2023
# **Subject:** Report on Predictive Policing System Disparities & Remediation Plan
#
# ---
#
# ### **Executive Summary**
#
# Our audit confirms the AI-based predictive policing system disproportionately targets minority neighborhoods. This disparity arises from a combination of **technical flaws** (biased training data, label bias, feedback loops) and **non-technical factors** (historical policing patterns, socio-economic confounders, deployment decisions). Left unaddressed, the system risks exacerbating inequality, eroding community trust, and violating civil rights. This report provides a causal analysis, a 12-month remediation plan, an independent audit protocol, a principled trade-off framework, and key questions for officials. **I recommend the council immediately suspend the system’s use for patrol decisions and initiate the proposed remediation plan.**
#
# ---
#
# ### **1. Causes of Disparity**
#
# #### **Technical Causes**
# - **Biased Training Data:** Historical crime data reflect over-policing of minority neighborhoods (e.g., higher arrest rates for low-level offenses), embedding past bias into predictions (*“garbage in, garbage out”*).
# - **Label Bias:** Using arrests or reported crimes as “crime” labels conflates crime prevalence with policing intensity. This is a well-documented source of bias (e.g., Lum & Isaac, 2016).
# - **Feedback Loops:** Predicted hotspots lead to more patrols, which generate more recorded incidents, reinforcing future predictions (a “self-fulfilling prophecy”).
# - **Deployment Decisions:** Thresholds for “high risk” may be set without fairness considerations, amplifying disparities.
#
# #### **Non-Technical Causes**
# - **Policing Practices:** Resource allocation, officer discretion, and community reporting rates differ across neighborhoods.
# - **Socio-Economic Confounders:** Poverty, density, and unemployment correlate with both minority status and some crime types—the system may proxy race via these variables.
# - **Vendor Contract & Oversight:** Lack of transparency in proprietary algorithms, absence of fairness constraints in procurement.
#
# ---
#
# ### **2. 12-Month Remediation Plan**
#
# | Priority | Action | Timeline | Resources Needed | Expected Impact on Disparity/Public Safety | Unintended Consequences/Risks |
# |----------|--------|----------|------------------|--------------------------------------------|-------------------------------|
# | **1. Immediate Safeguards** | Suspend system for patrol allocation; retain for internal analysis only. | Week 1 | Legal review, IT patch. | Halts amplification of bias; short-term uncertainty in patrol planning. | Officer pushback; potential temporary rise in response times. |
# | **2. Data & Model Audit** | Commission independent audit of training data, labels, and model outputs (see Section 4). | Months 1–3 | $80K–$120K for auditors; data engineer (city staff). | Identifies specific bias sources; informs model redesign. | Vendor resistance; may reveal deeper systemic biases. |
# | **3. Community Engagement** | Form oversight board with community reps, public defenders, civil rights advocates. | Months 1–12 (ongoing) | 0.5 FTE coordinator; stipends for community members. | Builds trust, ensures accountability, informs fairness criteria. | Board may lack technical expertise; potential for divisiveness. |
# | **4. Model & Process Redesign** | Redesign system with fairness constraints (e.g., demographic parity, equalized FPR), use alternative data (e.g., 911 calls only), and implement “fairness through awareness” (Dwork et al., 2012). | Months 4–9 | Data scientists (2 FTE), vendor renegotiation ($150K–$300K). | Reduces disparity; may slightly reduce accuracy for majority groups. | Trade-offs between fairness/accuracy; requires careful validation. |
# | **5. Policy & Contract Changes** | Update procurement to require fairness reports, transparency, and city ownership of data/models. | Months 6–12 | Legal, procurement staff. | Prevents future vendor lock-in and black-box systems. | Higher upfront costs; vendors may resist. |
# | **6. Pilot & Monitor** | Pilot revised system in limited districts with pre-specified fairness thresholds. | Months 10–12 | Patrol coordination, monitoring team. | Allows real-world testing of fairness/accuracy trade-offs. | Possible community skepticism even with improvements. |
#
# ---
#
# ### **3. Action Details & Confidence**
#
# - **Immediate Suspension:** *High confidence* based on precedent (e.g., NYPD’s early predictive policing issues). Key uncertainty: contractual penalties with vendor.
# - **Independent Audit:** *High confidence*; necessary for diagnosing specific bias. Uncertainty: data accessibility.
# - **Community Oversight Board:** *Medium confidence*; critical for legitimacy, but effectiveness depends on representation and authority.
# - **Model Redesign:** *Medium confidence*; technical solutions exist but require careful implementation to avoid other harms.
#
# ---
#
# ### **4. Independent Audit Protocol**
#
# **Objective:** Detect disparate harms in predictions vs. outcomes.
#
# **Data Required:**
# - Model predictions (by location/demographic).
# - Ground-truth crime data (victimization surveys, 911 calls).
# - Patrol records (stops, arrests, use of force).
# - Demographic data (census, neighborhood composition).
#
# **Statistical Tests:**
# - **Disparate Impact Ratio:** Compare prediction rates across racial groups.
# - **Error Rate Analysis:** False positive/negative rates by group.
# - **Causal Tests:** Instrumental variables or difference-in-differences to assess feedback loops.
#
# **Acceptable Thresholds:**
# - 80% rule (disparate impact ratio ≥0.8) for initial screening.
# - Statistical significance (p<0.05) for error rate differences.
# - **Action Trigger:** Any violation requires mitigation before redeployment.
#
# **Auditor Independence:**
# - Third-party selection by council + community board.
# - Full transparency: public report, code, and data (where privacy-safe).
#
# ---
#
# ### **5. Principled Trade-Off Framework**
#
# Council should adopt a **“Fairness, Accountability, and Transparency”** framework:
#
# 1. **Operationalize Fairness:** Choose a fairness metric (e.g., equalized false positive rates) based on community input and legal advice. Different definitions (e.g., demographic parity vs. equalized odds) have different trade-offs (Kleinberg et al., 2017).
# 2. **Accept Accuracy Reductions:** If needed, prioritize reducing disparities over marginal gains in overall prediction accuracy. Precedent: Berkeley’s dropped predictive policing due to equity concerns.
# 3. **Monitor Outcomes:** Track both crime rates and community trust metrics (surveys, complaint rates). Use control districts without the system for comparison.
# 4. **Decision Rule:** System redeployment only if it meets pre-agreed fairness thresholds and does not increase disproportionate stops/arrests.
#
# ---
#
# ### **6. Top Five Factual Questions for City/Vendor**
#
# 1. **“What specific crime data and labels were used to train the model?”**
#    - *If arrest data only:* Urgent need to switch to victimization data.
#    - *If mixed sources:* Audit label definitions for bias.
#
# 2. **“How are model predictions translated into patrol decisions (thresholds, human override)?”**
#    - *If fully automated:* Immediate need for human-in-the-loop.
#    - *If discretionary:* Assess officer training and guidelines.
#
# 3. **“What fairness tests were conducted before deployment, and what disparities were found?”**
#    - *If none:* Indicates vendor negligence; consider contract termination.
#    - *If tests showed disparities but were ignored:* Need policy changes to mandate fairness.
#
# 4. **“What is the contractual exit cost and data ownership status?”**
#    - *If high exit cost:* Phase out while developing in-house capacity.
#    - *If city owns data/model:* More flexibility for redesign.
#
# 5. **“What is the historical disparity in police stops/arrests by neighborhood, independent of the AI system?”**
#    - *If high:* System may be amplifying existing bias; need broader policing reform.
#    - *If low:* Suggests technical flaws dominate.
#
# ---
#
# ### **Recommendation**
#
# **The council should immediately suspend the system’s operational use, commission an independent audit, and establish a community oversight board.** These steps halt harm, diagnose root causes, and ensure community voice in remediation. The proposed 12-month plan balances urgency with feasibility, addressing both technical and systemic factors. Continuing without intervention risks legal liability, deepened distrust, and perpetuation of inequity.
#
# ---
# **Confidence:** High for immediate suspension and audit; medium for long-term redesign due to vendor and data uncertainties.
# **Citations:** Lum & Isaac (2016), Dwork et al. (2012), Kleinberg et al. (2017), Berk et al. (2021) on fairness trade-offs.
#
# # Response from competitor 4
#
# **Report: Remediation Plan for AI‑Based Predictive Policing System**
#
# **I. Introduction**
#
# The city's AI-based predictive policing system has been shown to disproportionately target minority neighborhoods, raising concerns about systemic bias and potential harm to communities of color. This report aims to provide a comprehensive analysis of the plausible causes of the disparity and proposed a prioritized 12-month remediation plan to address these issues.
#
# **II. Causes of Disparity**
#
# Technical causes:
#
# 1. **Biased training data**: Inadequate or skewed training datasets can perpetuate existing biases.
# 2. **Label bias**: Labelling patterns in historical crime data may reflect discrimination against minority groups.
# 3. **Feedback loops**: The system's self-reinforcing nature can amplify biased assumptions and predictions.
#
# Non-technical causes:
#
# 1. **Policing practices**: Aggressive policing tactics, racial profiling, and over-policing of minority neighborhoods contribute to the disparity.
# 2. **Socio-economic confounders**: Systematic differences in poverty rates, education levels, and employment opportunities across neighborhoods can skew crime data.
# 3. **Deployment decisions**: The system's algorithms are deployed without adequate consideration for community context, exacerbating biases.
#
# **III. Remediation Plan**
#
# A. Immediate Safeguards (Months 1-3)
#
# 1. **Data audit**: Conduct a thorough review of training data to identify patterns and biases (Estimated impact on disparity: −20%).
# 2. **System auditing**: Perform regular checks for updates, anomalies, and bias-related issues.
# 3. **Community outreach**: Engage in community forums to raise awareness and establish a dialogue on AI-based policing.
#
# B. Data and Model Updates (Months 4-6)
#
# 1. **Model adjustments**: Implement data-driven updates to reduce bias in algorithms ($100,000 - $300,000).
# 2. **Training dataset refresh**: Regularly update training datasets to reflect changing community demographics.
# 3. **External validation**: Engage with independent experts for model testing and validation.
#
# C. Deployment and Decision-Making Changes (Months 7-9)
#
# 1. **Algorithmic adjustments**: Implement algorithms that prioritize contextual understanding over simplistic rules ($150,000 - $400,000).
# 2. **Deployment guidelines**: Develop and deploy guidelines to address potential biases in deployment decisions.
# 3. **Training for officers**: Provide training on AI-based policing tools and their limitations.
#
# D. Community Engagement and Oversight (Months 10-12)
#
# 1. **Community advisory board**: Establish an independent community board to monitor the system's performance.
# 2. **Regular audits**: Perform quarterly audits to assess disparities and adjust mitigation strategies as needed.
# 3. **Policy oversight**: Conduct regular review of policy changes aligning with community feedback and expert input.
#
# E. Policy and Contractual Changes (Months 12-18)
#
# 1. **Racial bias policy**: Develop a city-wide policy on AI-based policing, emphasizing fairness and equity ($200,000 - $500,000).
# 2. **Vendor contract reviews**: Conduct regular reviews of contracts with vendors to ensure compliance with bias mitigation measures.
# 3. **Transparency reporting**: Establish clear reporting guidelines for transparency regarding the system's performance.
#
# **IV. Independent Audit Protocol**
#
# A. Data Collection:
#
# 1. Disaggregate crime data by neighborhood type and demographic groupings.
# 2. Analyze deployment patterns, response rates, and outcomes (e.g., arrests, convictions).
#
# B. Statistical and Causal Tests:
#
# 1. Apply regression analysis to assess disparities in historical crime data.
# 2. Employ causality tests to determine whether algorithmic predictions lead to distinct changes in policing behaviors.
#
# C. Acceptable Thresholds for Action:
#
# 1. Establish benchmarks for disparity reduction targets (e.g., 15%); adjust these as necessary.
# 2. Engage with local experts and civil society organizations to set thresholds for bias recognition.
#
# D. Auditor Independence and Transparency
#
# 1. Ensure the independent auditor has no direct affiliation with vendors or internal stakeholders.
# 2. Implement a structured process for sharing findings, recommendations, and system evaluation data with relevant city departments, community boards, and external stakeholders.
#
# **V. Principles for Tradeoff Between Predictive Accuracy, Public Safety, and Civil-Rights Protections**
#
# To balance predictive accuracy, public safety, and civil-rights protections:
#
# 1. **Data-driven decision-making**: Leverage objective data to underpin policing decisions.
# 2. **Algorithmic explainability**: Ensure algorithms provide robust explanations for recommendations.
# 3. **Community-centric approaches**: Prioritize contextual understanding and feedback from affected communities.
#
# These core principles inform adjustments in model deployment, decision-making processes, and ongoing community engagement throughout the project timeline.
#
# **VI. Top Five Questions to Ask City Officials or Vendors**
#
# 1. What data sources were used to develop the predictive policing system?
# 2. How has the system been validated against diverse training datasets, including samples representing minority populations?
#
# **VII. Conclusion and Confidence Level**
#
# This report emphasizes a 12-month remediation plan focused on immediate safeguards, ongoing audits, strategic software updates, deployment changes, and community oversight. To ensure our recommendations are effective, I set high confidence levels across most measures. However, uncertainties related to data availability, model explanations, vendor compliance with regulations, and societal perceptions of AI must be addressed.
#
# The best path forward is that the council engages in this collaborative framework with local stakeholders to identify specific questions and address emerging concerns.
#
# We recommend:
#
# 1. The city implement these measures to address disparity.
# 2. Regular community engagement ensures buy-in for systemic improvements.
#
# These priorities will allow the system to improve its performance and prioritize protection over prediction
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "3", "4", "2"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gpt-5-nano
# Rank 2: deepseek-chat
# Rank 3: llama3.2
# Rank 4: claude-sonnet-4-6

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
